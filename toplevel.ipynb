# %%
# %load_ext autoreload
# %autoreload 2

# %%
from XOR import Population, Genome, Connection, Specie
Specie.threshold
# Out:
# 3

# %%
INPUT = [[0,0], [0,1], [1,0], [1,1]]
OUTPUT = [0, 1, 1, 0]
p = Population(50, INPUT, OUTPUT, (2,1) )
p.run()
# Out:
# Generation 0 Best fitness 0
# Specie 0, pop:$51, avg f0.078 has 50 offspring when total av is $0.078
# generation 0 had 0 zeroed genomes
# Generation 1 Best fitness 4.0
# Specie 0, pop:$47, avg f0.085 has 3 offspring when total av is $1.418
# Specie 1, pop:$3, avg f1.333 has 47 offspring when total av is $1.418
# generation 1 had 0 zeroed genomes
# Generation 2 Best fitness 4.0
# Specie 0, pop:$5, avg f0.8 has 13 offspring when total av is $2.893
# Specie 1, pop:$43, avg f0.093 has 1 offspring when total av is $2.893
# Specie 2, pop:$2, avg f2.0 has 34 offspring when total av is $2.893
# generation 2 had 0 zeroed genomes
# Generation 3 Best fitness 4.0
# Specie 0, pop:$15, avg f0.267 has 3 offspring when total av is $4.388
# Specie 1, pop:$1, avg f4.0 has 45 offspring when total av is $4.388
# Specie 2, pop:$33, avg f0.121 has 1 offspring when total av is $4.388
# generation 3 had 0 zeroed genomes
# Generation 4 Best fitness 4.0
# Specie 0, pop:$5, avg f0.8 has 13 offspring when total av is $2.893
# Specie 1, pop:$43, avg f0.093 has 1 offspring when total av is $2.893
# Specie 2, pop:$2, avg f2.0 has 34 offspring when total av is $2.893
# generation 4 had 0 zeroed genomes
# Generation 5 Best fitness 4.0
# Specie 0, pop:$15, avg f0.267 has 3 offspring when total av is $4.396
# Specie 1, pop:$1, avg f4.0 has 45 offspring when total av is $4.396
# Specie 2, pop:$31, avg f0.129 has 1 offspring when total av is $4.396
# generation 5 had 0 zeroed genomes
# Generation 6 Best fitness 4.0
# Specie 0, pop:$5, avg f0.8 has 8 offspring when total av is $4.895
# Specie 1, pop:$42, avg f0.095 has 0 offspring when total av is $4.895
# Specie 2, pop:$1, avg f4.0 has 40 offspring when total av is $4.895
# generation 6 had 0 zeroed genomes
# Generation 7 Best fitness 4.0
# Specie 0, pop:$10, avg f0.4 has 4 offspring when total av is $4.503
# Specie 1, pop:$1, avg f4.0 has 44 offspring when total av is $4.503
# Specie 2, pop:$39, avg f0.103 has 1 offspring when total av is $4.503
# generation 7 had 0 zeroed genomes
# Generation 8 Best fitness 4.0
# Specie 0, pop:$6, avg f0.667 has 43 offspring when total av is $0.76
# Specie 1, pop:$43, avg f0.093 has 6 offspring when total av is $0.76
# generation 8 had 0 zeroed genomes
# Generation 9 Best fitness 4.0
# Specie 0, pop:$42, avg f0.095 has 7 offspring when total av is $0.667
# Specie 1, pop:$7, avg f0.571 has 42 offspring when total av is $0.667
# generation 9 had 0 zeroed genomes
# Generation 10 Best fitness 4.0
# Specie 0, pop:$9, avg f0.444 has 41 offspring when total av is $0.54
# Specie 1, pop:$42, avg f0.095 has 8 offspring when total av is $0.54
# generation 10 had 0 zeroed genomes
# Generation 11 Best fitness 4.0
# Specie 0, pop:$50, avg f0.08 has 50 offspring when total av is $0.08
# generation 11 had 0 zeroed genomes
# Generation 12 Best fitness 4.0
# Specie 0, pop:$1, avg f4.0 has 24 offspring when total av is $8.083
# Specie 1, pop:$48, avg f0.083 has 0 offspring when total av is $8.083
# Specie 2, pop:$1, avg f4.0 has 24 offspring when total av is $8.083
# generation 12 had 0 zeroed genomes
# Generation 13 Best fitness 4.0
# Specie 0, pop:$21, avg f0.19 has 1 offspring when total av is $6.372
# Specie 1, pop:$2, avg f2.0 has 15 offspring when total av is $6.372
# Specie 2, pop:$22, avg f0.182 has 1 offspring when total av is $6.372
# Specie 3, pop:$1, avg f4.0 has 31 offspring when total av is $6.372
# generation 13 had 0 zeroed genomes
# Generation 14 Best fitness 4.0
# Specie 0, pop:$1, avg f4.0 has 34 offspring when total av is $5.743
# Specie 1, pop:$15, avg f0.267 has 2 offspring when total av is $5.743
# Specie 2, pop:$3, avg f1.333 has 11 offspring when total av is $5.743
# Specie 3, pop:$28, avg f0.143 has 1 offspring when total av is $5.743
# generation 14 had 0 zeroed genomes
# Generation 15 Best fitness 4.0
# Specie 0, pop:$32, avg f0.125 has 1 offspring when total av is $5.525
# Specie 1, pop:$4, avg f1.0 has 9 offspring when total av is $5.525
# Specie 2, pop:$10, avg f0.4 has 3 offspring when total av is $5.525
# Specie 3, pop:$1, avg f4.0 has 36 offspring when total av is $5.525
# generation 15 had 0 zeroed genomes
# Generation 16 Best fitness 4.0
# Specie 0, pop:$1, avg f4.0 has 36 offspring when total av is $5.518
# Specie 1, pop:$10, avg f0.4 has 3 offspring when total av is $5.518
# Specie 2, pop:$4, avg f1.0 has 9 offspring when total av is $5.518
# Specie 3, pop:$34, avg f0.118 has 1 offspring when total av is $5.518
# generation 16 had 0 zeroed genomes
# Generation 17 Best fitness 4.0
# Specie 0, pop:$33, avg f0.121 has 1 offspring when total av is $5.421
# Specie 1, pop:$5, avg f0.8 has 7 offspring when total av is $5.421
# Specie 2, pop:$8, avg f0.5 has 4 offspring when total av is $5.421
# Specie 3, pop:$1, avg f4.0 has 36 offspring when total av is $5.421
# generation 17 had 0 zeroed genomes
# Generation 18 Best fitness 4.0
# Specie 0, pop:$1, avg f4.0 has 35 offspring when total av is $5.562
# Specie 1, pop:$9, avg f0.444 has 3 offspring when total av is $5.562
# Specie 2, pop:$4, avg f1.0 has 8 offspring when total av is $5.562
# Specie 3, pop:$34, avg f0.118 has 1 offspring when total av is $5.562
# generation 18 had 1 zeroed genomes
# Generation 19 Best fitness 4.0
# Specie 0, pop:$34, avg f0.118 has 1 offspring when total av is $5.356
# Specie 1, pop:$6, avg f0.667 has 6 offspring when total av is $5.356
# Specie 2, pop:$7, avg f0.571 has 5 offspring when total av is $5.356
# Specie 3, pop:$1, avg f4.0 has 37 offspring when total av is $5.356
# generation 19 had 0 zeroed genomes
# Generation 20 Best fitness 4.0
# Specie 0, pop:$1, avg f4.0 has 36 offspring when total av is $5.411
# Specie 1, pop:$8, avg f0.5 has 4 offspring when total av is $5.411
# Specie 2, pop:$5, avg f0.8 has 7 offspring when total av is $5.411
# Specie 3, pop:$36, avg f0.111 has 1 offspring when total av is $5.411
# generation 20 had 0 zeroed genomes
# Generation 21 Best fitness 4.0
# Specie 0, pop:$36, avg f0.111 has 1 offspring when total av is $5.349
# Specie 1, pop:$6, avg f0.667 has 6 offspring when total av is $5.349
# Specie 2, pop:$7, avg f0.571 has 5 offspring when total av is $5.349
# Specie 3, pop:$1, avg f4.0 has 37 offspring when total av is $5.349
# generation 21 had 0 zeroed genomes
# Generation 22 Best fitness 4.0
# Specie 0, pop:$1, avg f4.0 has 35 offspring when total av is $5.614
# Specie 1, pop:$8, avg f0.5 has 4 offspring when total av is $5.614
# Specie 2, pop:$4, avg f1.0 has 8 offspring when total av is $5.614
# Specie 3, pop:$35, avg f0.114 has 1 offspring when total av is $5.614
# generation 22 had 0 zeroed genomes
# Generation 23 Best fitness 4.0
# Specie 0, pop:$33, avg f0.121 has 0 offspring when total av is $9.455
# Specie 1, pop:$6, avg f0.667 has 3 offspring when total av is $9.455
# Specie 2, pop:$6, avg f0.667 has 3 offspring when total av is $9.455
# Specie 3, pop:$1, avg f4.0 has 21 offspring when total av is $9.455
# Specie 6, pop:$1, avg f4.0 has 21 offspring when total av is $9.455
# generation 23 had 0 zeroed genomes
# Generation 24 Best fitness 4.0
# Specie 1, pop:$5, avg f0.8 has 15 offspring when total av is $2.566
# Specie 2, pop:$3, avg f1.333 has 25 offspring when total av is $2.566
# Specie 3, pop:$18, avg f0.222 has 4 offspring when total av is $2.566
# Specie 6, pop:$19, avg f0.211 has 4 offspring when total av is $2.566
# generation 24 had 0 zeroed genomes
# Generation 25 Best fitness 4.0
# Specie 1, pop:$16, avg f0.25 has 4 offspring when total av is $2.743
# Specie 2, pop:$25, avg f0.16 has 2 offspring when total av is $2.743
# Specie 3, pop:$4, avg f1.0 has 18 offspring when total av is $2.743
# Specie 6, pop:$3, avg f1.333 has 24 offspring when total av is $2.743
# generation 25 had 0 zeroed genomes
# Generation 26 Best fitness 4.0
# Specie 1, pop:$6, avg f0.667 has 10 offspring when total av is $3.063
# Specie 2, pop:$2, avg f2.0 has 32 offspring when total av is $3.063
# Specie 3, pop:$18, avg f0.222 has 3 offspring when total av is $3.063
# Specie 6, pop:$23, avg f0.174 has 2 offspring when total av is $3.063
# generation 26 had 1 zeroed genomes
# Generation 27 Best fitness 4.0
# Specie 1, pop:$14, avg f0.286 has 3 offspring when total av is $3.748
# Specie 2, pop:$31, avg f0.129 has 1 offspring when total av is $3.748
# Specie 3, pop:$3, avg f1.333 has 17 offspring when total av is $3.748
# Specie 6, pop:$2, avg f2.0 has 26 offspring when total av is $3.748
# generation 27 had 1 zeroed genomes
# Generation 28 Best fitness 4.0
# Specie 1, pop:$6, avg f0.667 has 10 offspring when total av is $3.083
# Specie 2, pop:$2, avg f2.0 has 32 offspring when total av is $3.083
# Specie 3, pop:$16, avg f0.25 has 4 offspring when total av is $3.083
# Specie 6, pop:$24, avg f0.167 has 2 offspring when total av is $3.083
# generation 28 had 0 zeroed genomes
# Generation 29 Best fitness 4.0
# Specie 1, pop:$12, avg f0.333 has 4 offspring when total av is $3.462
# Specie 2, pop:$31, avg f0.129 has 1 offspring when total av is $3.462
# Specie 3, pop:$4, avg f1.0 has 14 offspring when total av is $3.462
# Specie 6, pop:$2, avg f2.0 has 28 offspring when total av is $3.462
# generation 29 had 1 zeroed genomes
# Generation 30 Best fitness 4.0
# Specie 1, pop:$7, avg f0.571 has 5 offspring when total av is $5.0
# Specie 2, pop:$1, avg f4.0 has 40 offspring when total av is $5.0
# Specie 3, pop:$14, avg f0.286 has 2 offspring when total av is $5.0
# Specie 6, pop:$28, avg f0.143 has 1 offspring when total av is $5.0
# generation 30 had 0 zeroed genomes
# Generation 31 Best fitness 4.0
# Specie 1, pop:$7, avg f0.571 has 2 offspring when total av is $10.677
# Specie 2, pop:$38, avg f0.105 has 0 offspring when total av is $10.677
# Specie 3, pop:$2, avg f2.0 has 9 offspring when total av is $10.677
# Specie 6, pop:$1, avg f4.0 has 18 offspring when total av is $10.677
# Specie 4, pop:$1, avg f4.0 has 18 offspring when total av is $10.677
# generation 31 had 1 zeroed genomes
# Generation 32 Best fitness 4.0
# Specie 1, pop:$5, avg f0.8 has 23 offspring when total av is $1.689
# Specie 3, pop:$9, avg f0.444 has 13 offspring when total av is $1.689
# Specie 6, pop:$18, avg f0.222 has 6 offspring when total av is $1.689
# Specie 4, pop:$18, avg f0.222 has 6 offspring when total av is $1.689
# generation 32 had 0 zeroed genomes
# Generation 33 Best fitness 4.0
# Specie 1, pop:$24, avg f0.167 has 4 offspring when total av is $1.864
# Specie 3, pop:$11, avg f0.364 has 9 offspring when total av is $1.864
# Specie 6, pop:$6, avg f0.667 has 17 offspring when total av is $1.864
# Specie 4, pop:$6, avg f0.667 has 17 offspring when total av is $1.864
# generation 33 had 1 zeroed genomes
# Generation 34 Best fitness 4.0
# Specie 1, pop:$6, avg f0.667 has 19 offspring when total av is $1.709
# Specie 3, pop:$7, avg f0.571 has 16 offspring when total av is $1.709
# Specie 6, pop:$17, avg f0.235 has 6 offspring when total av is $1.709
# Specie 4, pop:$17, avg f0.235 has 6 offspring when total av is $1.709
# generation 34 had 1 zeroed genomes
# Generation 35 Best fitness 4.0
# Specie 1, pop:$21, avg f0.19 has 4 offspring when total av is $1.924
# Specie 3, pop:$15, avg f0.267 has 6 offspring when total av is $1.924
# Specie 6, pop:$5, avg f0.8 has 20 offspring when total av is $1.924
# Specie 4, pop:$6, avg f0.667 has 17 offspring when total av is $1.924
# generation 35 had 1 zeroed genomes
# Generation 36 Best fitness 4.0
# Specie 1, pop:$7, avg f0.571 has 16 offspring when total av is $1.696
# Specie 3, pop:$6, avg f0.667 has 19 offspring when total av is $1.696
# Specie 6, pop:$18, avg f0.222 has 6 offspring when total av is $1.696
# Specie 4, pop:$17, avg f0.235 has 6 offspring when total av is $1.696
# generation 36 had 1 zeroed genomes
# Generation 37 Best fitness 4.0
# Specie 1, pop:$17, avg f0.235 has 2 offspring when total av is $5.804
# Specie 3, pop:$17, avg f0.235 has 2 offspring when total av is $5.804
# Specie 6, pop:$6, avg f0.667 has 5 offspring when total av is $5.804
# Specie 4, pop:$6, avg f0.667 has 5 offspring when total av is $5.804
# Specie 4, pop:$1, avg f4.0 has 34 offspring when total av is $5.804
# generation 37 had 0 zeroed genomes
# Generation 38 Best fitness 4.0
# Specie 1, pop:$4, avg f1.0 has 10 offspring when total av is $4.588
# Specie 3, pop:$2, avg f2.0 has 21 offspring when total av is $4.588
# Specie 6, pop:$5, avg f0.8 has 8 offspring when total av is $4.588
# Specie 4, pop:$6, avg f0.667 has 7 offspring when total av is $4.588
# Specie 4, pop:$33, avg f0.121 has 1 offspring when total av is $4.588
# generation 38 had 1 zeroed genomes
# Generation 39 Best fitness 4.0
# Specie 1, pop:$13, avg f0.308 has 2 offspring when total av is $5.641
# Specie 3, pop:$21, avg f0.19 has 1 offspring when total av is $5.641
# Specie 6, pop:$7, avg f0.571 has 5 offspring when total av is $5.641
# Specie 4, pop:$7, avg f0.571 has 5 offspring when total av is $5.641
# Specie 4, pop:$1, avg f4.0 has 35 offspring when total av is $5.641
# generation 39 had 0 zeroed genomes
# Generation 40 Best fitness 4.0
# Specie 1, pop:$4, avg f1.0 has 7 offspring when total av is $6.788
# Specie 3, pop:$1, avg f4.0 has 29 offspring when total av is $6.788
# Specie 6, pop:$4, avg f1.0 has 7 offspring when total av is $6.788
# Specie 4, pop:$6, avg f0.667 has 4 offspring when total av is $6.788
# Specie 4, pop:$33, avg f0.121 has 0 offspring when total av is $6.788
# generation 40 had 1 zeroed genomes
# Generation 41 Best fitness 4.0
# Specie 1, pop:$10, avg f0.4 has 7 offspring when total av is $2.676
# Specie 3, pop:$28, avg f0.143 has 2 offspring when total av is $2.676
# Specie 6, pop:$5, avg f0.8 has 14 offspring when total av is $2.676
# Specie 4, pop:$3, avg f1.333 has 24 offspring when total av is $2.676
# generation 41 had 1 zeroed genomes
# Generation 42 Best fitness 4.0
# Specie 1, pop:$10, avg f0.4 has 6 offspring when total av is $2.89
# Specie 3, pop:$2, avg f2.0 has 34 offspring when total av is $2.89
# Specie 6, pop:$13, avg f0.308 has 5 offspring when total av is $2.89
# Specie 4, pop:$22, avg f0.182 has 3 offspring when total av is $2.89
# generation 42 had 0 zeroed genomes
# Generation 43 Best fitness 4.0
# Specie 1, pop:$8, avg f0.5 has 6 offspring when total av is $3.629
# Specie 3, pop:$31, avg f0.129 has 1 offspring when total av is $3.629
# Specie 6, pop:$4, avg f1.0 has 13 offspring when total av is $3.629
# Specie 4, pop:$2, avg f2.0 has 27 offspring when total av is $3.629
# generation 43 had 1 zeroed genomes
# Generation 44 Best fitness 4.0
# Specie 1, pop:$8, avg f0.5 has 5 offspring when total av is $4.993
# Specie 3, pop:$1, avg f4.0 has 40 offspring when total av is $4.993
# Specie 6, pop:$12, avg f0.333 has 3 offspring when total av is $4.993
# Specie 4, pop:$25, avg f0.16 has 1 offspring when total av is $4.993
# generation 44 had 0 zeroed genomes
# Generation 45 Best fitness 4.0
# Specie 1, pop:$7, avg f0.571 has 2 offspring when total av is $10.019
# Specie 3, pop:$35, avg f0.114 has 0 offspring when total av is $10.019
# Specie 6, pop:$3, avg f1.333 has 6 offspring when total av is $10.019
# Specie 4, pop:$1, avg f4.0 has 19 offspring when total av is $10.019
# Specie 7, pop:$1, avg f4.0 has 19 offspring when total av is $10.019
# generation 45 had 2 zeroed genomes
# Generation 46 Best fitness 4.0
# Specie 1, pop:$6, avg f0.667 has 5 offspring when total av is $5.794
# Specie 3, pop:$1, avg f4.0 has 34 offspring when total av is $5.794
# Specie 6, pop:$6, avg f0.667 has 5 offspring when total av is $5.794
# Specie 4, pop:$19, avg f0.211 has 1 offspring when total av is $5.794
# Specie 7, pop:$16, avg f0.25 has 2 offspring when total av is $5.794
# generation 46 had 1 zeroed genomes
# Generation 47 Best fitness 4.0
# Specie 1, pop:$7, avg f0.571 has 5 offspring when total av is $5.489
# Specie 3, pop:$34, avg f0.118 has 1 offspring when total av is $5.489
# Specie 6, pop:$5, avg f0.8 has 7 offspring when total av is $5.489
# Specie 4, pop:$1, avg f4.0 has 36 offspring when total av is $5.489
# generation 47 had 0 zeroed genomes
# Generation 48 Best fitness 4.0
# Specie 1, pop:$7, avg f0.571 has 5 offspring when total av is $5.264
# Specie 3, pop:$1, avg f4.0 has 37 offspring when total av is $5.264
# Specie 6, pop:$7, avg f0.571 has 5 offspring when total av is $5.264
# Specie 4, pop:$33, avg f0.121 has 1 offspring when total av is $5.264
# generation 48 had 0 zeroed genomes
# Generation 49 Best fitness 4.0
# Specie 1, pop:$7, avg f0.571 has 5 offspring when total av is $5.48
# Specie 3, pop:$37, avg f0.108 has 0 offspring when total av is $5.48
# Specie 6, pop:$5, avg f0.8 has 7 offspring when total av is $5.48
# Specie 4, pop:$1, avg f4.0 has 36 offspring when total av is $5.48
# generation 49 had 0 zeroed genomes
# Generation 50 Best fitness 4.0
# Specie 1, pop:$7, avg f0.571 has 21 offspring when total av is $1.356
# Specie 6, pop:$6, avg f0.667 has 24 offspring when total av is $1.356
# Specie 4, pop:$34, avg f0.118 has 4 offspring when total av is $1.356
# generation 50 had 0 zeroed genomes
# Generation 51 Best fitness 4.0
# Specie 1, pop:$22, avg f0.182 has 3 offspring when total av is $2.348
# Specie 6, pop:$24, avg f0.167 has 3 offspring when total av is $2.348
# Specie 4, pop:$2, avg f2.0 has 42 offspring when total av is $2.348
# generation 51 had 0 zeroed genomes
# Generation 52 Best fitness 4.0
# Specie 1, pop:$4, avg f1.0 has 7 offspring when total av is $6.436
# Specie 6, pop:$3, avg f1.333 has 10 offspring when total av is $6.436
# Specie 4, pop:$39, avg f0.103 has 0 offspring when total av is $6.436
# Specie 4, pop:$1, avg f4.0 has 31 offspring when total av is $6.436
# generation 52 had 0 zeroed genomes
# Generation 53 Best fitness 4.0
# Specie 1, pop:$8, avg f0.5 has 4 offspring when total av is $5.082
# Specie 6, pop:$9, avg f0.444 has 4 offspring when total av is $5.082
# Specie 4, pop:$1, avg f4.0 has 39 offspring when total av is $5.082
# Specie 4, pop:$29, avg f0.138 has 1 offspring when total av is $5.082
# generation 53 had 0 zeroed genomes
# Generation 54 Best fitness 4.0
# Specie 1, pop:$6, avg f0.667 has 18 offspring when total av is $1.767
# Specie 6, pop:$4, avg f1.0 has 28 offspring when total av is $1.767
# Specie 4, pop:$40, avg f0.1 has 2 offspring when total av is $1.767
# generation 54 had 0 zeroed genomes
# Generation 55 Best fitness 4.0
# Specie 1, pop:$20, avg f0.2 has 4 offspring when total av is $2.348
# Specie 6, pop:$27, avg f0.148 has 3 offspring when total av is $2.348
# Specie 4, pop:$2, avg f2.0 has 42 offspring when total av is $2.348
# generation 55 had 0 zeroed genomes
# Generation 56 Best fitness 4.0
# Specie 1, pop:$6, avg f0.667 has 15 offspring when total av is $2.103
# Specie 6, pop:$3, avg f1.333 has 31 offspring when total av is $2.103
# Specie 4, pop:$39, avg f0.103 has 2 offspring when total av is $2.103
# generation 56 had 0 zeroed genomes
# Generation 57 Best fitness 4.0
# Specie 1, pop:$16, avg f0.25 has 5 offspring when total av is $2.383
# Specie 6, pop:$30, avg f0.133 has 2 offspring when total av is $2.383
# Specie 4, pop:$2, avg f2.0 has 41 offspring when total av is $2.383
# generation 57 had 0 zeroed genomes
# Generation 58 Best fitness 4.0
# Specie 1, pop:$7, avg f0.571 has 4 offspring when total av is $6.68
# Specie 6, pop:$2, avg f2.0 has 14 offspring when total av is $6.68
# Specie 4, pop:$37, avg f0.108 has 0 offspring when total av is $6.68
# Specie 3, pop:$1, avg f4.0 has 29 offspring when total av is $6.68
# generation 58 had 1 zeroed genomes
# Generation 59 Best fitness 4.0
# Specie 1, pop:$7, avg f0.571 has 5 offspring when total av is $5.005
# Specie 6, pop:$14, avg f0.286 has 2 offspring when total av is $5.005
# Specie 3, pop:$27, avg f0.148 has 1 offspring when total av is $5.005
# Specie 4, pop:$1, avg f4.0 has 39 offspring when total av is $5.005
# generation 59 had 1 zeroed genomes
# Generation 60 Best fitness 4.0
# Specie 1, pop:$8, avg f0.5 has 3 offspring when total av is $6.605
# Specie 6, pop:$2, avg f2.0 has 15 offspring when total av is $6.605
# Specie 3, pop:$1, avg f4.0 has 30 offspring when total av is $6.605
# Specie 4, pop:$38, avg f0.105 has 0 offspring when total av is $6.605
# generation 60 had 0 zeroed genomes
# Generation 61 Best fitness 4.0
# Specie 1, pop:$5, avg f0.8 has 31 offspring when total av is $1.251
# Specie 6, pop:$13, avg f0.308 has 12 offspring when total av is $1.251
# Specie 3, pop:$28, avg f0.143 has 5 offspring when total av is $1.251
# generation 61 had 0 zeroed genomes
# Generation 62 Best fitness 4.0
# Specie 1, pop:$31, avg f0.129 has 1 offspring when total av is $5.293
# Specie 6, pop:$11, avg f0.364 has 3 offspring when total av is $5.293
# Specie 3, pop:$5, avg f0.8 has 7 offspring when total av is $5.293
# Specie 3, pop:$1, avg f4.0 has 37 offspring when total av is $5.293
# generation 62 had 0 zeroed genomes
# Generation 63 Best fitness 4.0
# Specie 1, pop:$3, avg f1.333 has 19 offspring when total av is $3.455
# Specie 6, pop:$3, avg f1.333 has 19 offspring when total av is $3.455
# Specie 3, pop:$6, avg f0.667 has 9 offspring when total av is $3.455
# Specie 3, pop:$33, avg f0.121 has 1 offspring when total av is $3.455
# generation 63 had 0 zeroed genomes
# Generation 64 Best fitness 4.0
# Specie 1, pop:$21, avg f0.19 has 11 offspring when total av is $0.845
# Specie 6, pop:$19, avg f0.211 has 12 offspring when total av is $0.845
# Specie 3, pop:$9, avg f0.444 has 26 offspring when total av is $0.845
# generation 64 had 0 zeroed genomes
# Generation 65 Best fitness 4.0
# Specie 1, pop:$13, avg f0.308 has 19 offspring when total av is $0.808
# Specie 6, pop:$12, avg f0.333 has 20 offspring when total av is $0.808
# Specie 3, pop:$24, avg f0.167 has 10 offspring when total av is $0.808
# generation 65 had 0 zeroed genomes
# Generation 66 Best fitness 4.0
# Specie 1, pop:$18, avg f0.222 has 13 offspring when total av is $0.822
# Specie 6, pop:$20, avg f0.2 has 12 offspring when total av is $0.822
# Specie 3, pop:$10, avg f0.4 has 24 offspring when total av is $0.822
# generation 66 had 0 zeroed genomes
# Generation 67 Best fitness 4.0
# Specie 1, pop:$15, avg f0.267 has 16 offspring when total av is $0.797
# Specie 6, pop:$11, avg f0.364 has 22 offspring when total av is $0.797
# Specie 3, pop:$24, avg f0.167 has 10 offspring when total av is $0.797
# generation 67 had 0 zeroed genomes
# Generation 68 Best fitness 4.0
# Specie 1, pop:$17, avg f0.235 has 13 offspring when total av is $0.87
# Specie 6, pop:$21, avg f0.19 has 10 offspring when total av is $0.87
# Specie 3, pop:$9, avg f0.444 has 25 offspring when total av is $0.87
# generation 68 had 0 zeroed genomes
# Generation 69 Best fitness 4.0
# Specie 1, pop:$15, avg f0.267 has 15 offspring when total av is $0.885
# Specie 6, pop:$9, avg f0.444 has 25 offspring when total av is $0.885
# Specie 3, pop:$23, avg f0.174 has 9 offspring when total av is $0.885
# generation 69 had 0 zeroed genomes
# Generation 70 Best fitness 4.0
# Specie 1, pop:$16, avg f0.25 has 14 offspring when total av is $0.854
# Specie 6, pop:$25, avg f0.16 has 9 offspring when total av is $0.854
# Specie 3, pop:$9, avg f0.444 has 26 offspring when total av is $0.854
# generation 70 had 0 zeroed genomes
# Generation 71 Best fitness 4.0
# Specie 1, pop:$15, avg f0.267 has 15 offspring when total av is $0.878
# Specie 6, pop:$9, avg f0.444 has 25 offspring when total av is $0.878
# Specie 3, pop:$24, avg f0.167 has 9 offspring when total av is $0.878
# generation 71 had 0 zeroed genomes
# Generation 72 Best fitness 4.0
# Specie 1, pop:$15, avg f0.267 has 2 offspring when total av is $4.933
# Specie 6, pop:$24, avg f0.167 has 1 offspring when total av is $4.933
# Specie 3, pop:$8, avg f0.5 has 5 offspring when total av is $4.933
# Specie 3, pop:$1, avg f4.0 has 40 offspring when total av is $4.933
# generation 72 had 0 zeroed genomes
# Generation 73 Best fitness 4.0
# Specie 1, pop:$4, avg f1.0 has 8 offspring when total av is $5.903
# Specie 6, pop:$1, avg f4.0 has 33 offspring when total av is $5.903
# Specie 3, pop:$5, avg f0.8 has 6 offspring when total av is $5.903
# Specie 3, pop:$39, avg f0.103 has 0 offspring when total av is $5.903
# generation 73 had 1 zeroed genomes
# Generation 74 Best fitness 4.0
# Specie 1, pop:$10, avg f0.4 has 16 offspring when total av is $1.192
# Specie 6, pop:$32, avg f0.125 has 5 offspring when total av is $1.192
# Specie 3, pop:$6, avg f0.667 has 27 offspring when total av is $1.192
# generation 74 had 0 zeroed genomes
# Generation 75 Best fitness 4.0
# Specie 1, pop:$17, avg f0.235 has 9 offspring when total av is $1.202
# Specie 6, pop:$5, avg f0.8 has 33 offspring when total av is $1.202
# Specie 3, pop:$24, avg f0.167 has 6 offspring when total av is $1.202
# generation 75 had 0 zeroed genomes
# Generation 76 Best fitness 4.0
# Specie 1, pop:$11, avg f0.364 has 15 offspring when total av is $1.152
# Specie 6, pop:$33, avg f0.121 has 5 offspring when total av is $1.152
# Specie 3, pop:$6, avg f0.667 has 28 offspring when total av is $1.152
# generation 76 had 0 zeroed genomes
# Generation 77 Best fitness 4.0
# Specie 1, pop:$17, avg f0.235 has 6 offspring when total av is $1.722
# Specie 6, pop:$3, avg f1.333 has 38 offspring when total av is $1.722
# Specie 3, pop:$26, avg f0.154 has 4 offspring when total av is $1.722
# generation 77 had 0 zeroed genomes
# Generation 78 Best fitness 4.0
# Specie 1, pop:$8, avg f0.5 has 2 offspring when total av is $9.958
# Specie 6, pop:$32, avg f0.125 has 0 offspring when total av is $9.958
# Specie 3, pop:$3, avg f1.333 has 6 offspring when total av is $9.958
# Specie 3, pop:$1, avg f4.0 has 20 offspring when total av is $9.958
# Specie 4, pop:$1, avg f4.0 has 20 offspring when total av is $9.958
# generation 78 had 0 zeroed genomes
# Generation 79 Best fitness 4.0
# Specie 1, pop:$4, avg f1.0 has 24 offspring when total av is $2.077
# Specie 3, pop:$6, avg f0.667 has 16 offspring when total av is $2.077
# Specie 3, pop:$20, avg f0.2 has 4 offspring when total av is $2.077
# Specie 4, pop:$19, avg f0.211 has 5 offspring when total av is $2.077
# generation 79 had 0 zeroed genomes
# Generation 80 Best fitness 4.0
# Specie 1, pop:$26, avg f0.154 has 3 offspring when total av is $2.204
# Specie 3, pop:$16, avg f0.25 has 5 offspring when total av is $2.204
# Specie 3, pop:$4, avg f1.0 has 22 offspring when total av is $2.204
# Specie 4, pop:$5, avg f0.8 has 18 offspring when total av is $2.204
# generation 80 had 0 zeroed genomes
# Generation 81 Best fitness 4.0
# Specie 1, pop:$5, avg f0.8 has 19 offspring when total av is $2.004
# Specie 3, pop:$5, avg f0.8 has 19 offspring when total av is $2.004
# Specie 3, pop:$22, avg f0.182 has 4 offspring when total av is $2.004
# Specie 4, pop:$18, avg f0.222 has 5 offspring when total av is $2.004
# generation 81 had 1 zeroed genomes
# Generation 82 Best fitness 4.0
# Specie 1, pop:$21, avg f0.19 has 4 offspring when total av is $2.201
# Specie 3, pop:$19, avg f0.211 has 4 offspring when total av is $2.201
# Specie 3, pop:$4, avg f1.0 has 22 offspring when total av is $2.201
# Specie 4, pop:$5, avg f0.8 has 18 offspring when total av is $2.201
# generation 82 had 0 zeroed genomes
# Generation 83 Best fitness 4.0
# Specie 1, pop:$6, avg f0.667 has 15 offspring when total av is $2.098
# Specie 3, pop:$4, avg f1.0 has 23 offspring when total av is $2.098
# Specie 3, pop:$22, avg f0.182 has 4 offspring when total av is $2.098
# Specie 4, pop:$16, avg f0.25 has 5 offspring when total av is $2.098
# generation 83 had 1 zeroed genomes
# Generation 84 Best fitness 4.0
# Specie 1, pop:$17, avg f0.235 has 5 offspring when total av is $2.209
# Specie 3, pop:$23, avg f0.174 has 3 offspring when total av is $2.209
# Specie 3, pop:$4, avg f1.0 has 22 offspring when total av is $2.209
# Specie 4, pop:$5, avg f0.8 has 18 offspring when total av is $2.209
# generation 84 had 0 zeroed genomes
# Generation 85 Best fitness 4.0
# Specie 1, pop:$7, avg f0.571 has 4 offspring when total av is $6.338
# Specie 3, pop:$3, avg f1.333 has 10 offspring when total av is $6.338
# Specie 3, pop:$19, avg f0.211 has 1 offspring when total av is $6.338
# Specie 4, pop:$18, avg f0.222 has 1 offspring when total av is $6.338
# Specie 5, pop:$1, avg f4.0 has 31 offspring when total av is $6.338
# generation 85 had 1 zeroed genomes
# Generation 86 Best fitness 4.0
# Specie 1, pop:$7, avg f0.571 has 3 offspring when total av is $9.109
# Specie 3, pop:$10, avg f0.4 has 2 offspring when total av is $9.109
# Specie 3, pop:$1, avg f4.0 has 21 offspring when total av is $9.109
# Specie 4, pop:$1, avg f4.0 has 21 offspring when total av is $9.109
# Specie 5, pop:$29, avg f0.138 has 0 offspring when total av is $9.109
# generation 86 had 1 zeroed genomes
# Generation 87 Best fitness 4.0
# Specie 1, pop:$5, avg f0.8 has 12 offspring when total av is $3.201
# Specie 3, pop:$2, avg f2.0 has 31 offspring when total av is $3.201
# Specie 3, pop:$19, avg f0.211 has 3 offspring when total av is $3.201
# Specie 4, pop:$21, avg f0.19 has 2 offspring when total av is $3.201
# generation 87 had 0 zeroed genomes
# Generation 88 Best fitness 4.0
# Specie 1, pop:$14, avg f0.286 has 3 offspring when total av is $3.762
# Specie 3, pop:$28, avg f0.143 has 1 offspring when total av is $3.762
# Specie 3, pop:$3, avg f1.333 has 17 offspring when total av is $3.762
# Specie 4, pop:$2, avg f2.0 has 26 offspring when total av is $3.762
# generation 88 had 1 zeroed genomes
# Generation 89 Best fitness 4.0
# Specie 1, pop:$6, avg f0.667 has 6 offspring when total av is $5.056
# Specie 3, pop:$1, avg f4.0 has 39 offspring when total av is $5.056
# Specie 3, pop:$17, avg f0.235 has 2 offspring when total av is $5.056
# Specie 4, pop:$26, avg f0.154 has 1 offspring when total av is $5.056
# generation 89 had 0 zeroed genomes
# Generation 90 Best fitness 4.0
# Specie 1, pop:$8, avg f0.5 has 3 offspring when total av is $6.605
# Specie 3, pop:$38, avg f0.105 has 0 offspring when total av is $6.605
# Specie 3, pop:$2, avg f2.0 has 15 offspring when total av is $6.605
# Specie 4, pop:$1, avg f4.0 has 30 offspring when total av is $6.605
# generation 90 had 0 zeroed genomes
# Generation 91 Best fitness 4.0
# Specie 1, pop:$4, avg f1.0 has 35 offspring when total av is $1.429
# Specie 3, pop:$14, avg f0.286 has 10 offspring when total av is $1.429
# Specie 4, pop:$28, avg f0.143 has 5 offspring when total av is $1.429
# generation 91 had 0 zeroed genomes
# Generation 92 Best fitness 4.0
# Specie 1, pop:$36, avg f0.111 has 3 offspring when total av is $1.511
# Specie 3, pop:$10, avg f0.4 has 13 offspring when total av is $1.511
# Specie 4, pop:$4, avg f1.0 has 33 offspring when total av is $1.511
# generation 92 had 0 zeroed genomes
# Generation 93 Best fitness 4.0
# Specie 1, pop:$5, avg f0.8 has 7 offspring when total av is $5.262
# Specie 3, pop:$12, avg f0.333 has 3 offspring when total av is $5.262
# Specie 4, pop:$31, avg f0.129 has 1 offspring when total av is $5.262
# Specie 4, pop:$1, avg f4.0 has 38 offspring when total av is $5.262
# generation 93 had 0 zeroed genomes
# Generation 94 Best fitness 4.0
# Specie 1, pop:$9, avg f0.444 has 2 offspring when total av is $9.889
# Specie 3, pop:$3, avg f1.333 has 6 offspring when total av is $9.889
# Specie 4, pop:$1, avg f4.0 has 20 offspring when total av is $9.889
# Specie 4, pop:$36, avg f0.111 has 0 offspring when total av is $9.889
# Specie 4, pop:$1, avg f4.0 has 20 offspring when total av is $9.889
# generation 94 had 0 zeroed genomes
# Generation 95 Best fitness 4.0
# Specie 1, pop:$4, avg f1.0 has 24 offspring when total av is $2.067
# Specie 3, pop:$6, avg f0.667 has 16 offspring when total av is $2.067
# Specie 4, pop:$20, avg f0.2 has 4 offspring when total av is $2.067
# Specie 4, pop:$20, avg f0.2 has 4 offspring when total av is $2.067
# generation 95 had 0 zeroed genomes
# Generation 96 Best fitness 4.0
# Specie 1, pop:$26, avg f0.154 has 2 offspring when total av is $2.754
# Specie 3, pop:$15, avg f0.267 has 4 offspring when total av is $2.754
# Specie 4, pop:$4, avg f1.0 has 18 offspring when total av is $2.754
# Specie 4, pop:$3, avg f1.333 has 24 offspring when total av is $2.754
# generation 96 had 0 zeroed genomes
# Generation 97 Best fitness 4.0
# Specie 1, pop:$4, avg f1.0 has 20 offspring when total av is $2.432
# Specie 3, pop:$4, avg f1.0 has 20 offspring when total av is $2.432
# Specie 4, pop:$16, avg f0.25 has 5 offspring when total av is $2.432
# Specie 4, pop:$22, avg f0.182 has 3 offspring when total av is $2.432
# generation 97 had 0 zeroed genomes
# Generation 98 Best fitness 4.0
# Specie 1, pop:$20, avg f0.2 has 1 offspring when total av is $6.756
# Specie 3, pop:$18, avg f0.222 has 1 offspring when total av is $6.756
# Specie 4, pop:$4, avg f1.0 has 7 offspring when total av is $6.756
# Specie 4, pop:$3, avg f1.333 has 9 offspring when total av is $6.756
# Specie 4, pop:$1, avg f4.0 has 29 offspring when total av is $6.756
# generation 98 had 1 zeroed genomes
# Generation 99 Best fitness 4.0
# Specie 1, pop:$4, avg f1.0 has 8 offspring when total av is $6.214
# Specie 3, pop:$1, avg f4.0 has 32 offspring when total av is $6.214
# Specie 4, pop:$7, avg f0.571 has 4 offspring when total av is $6.214
# Specie 4, pop:$8, avg f0.5 has 4 offspring when total av is $6.214
# Specie 4, pop:$28, avg f0.143 has 1 offspring when total av is $6.214
# generation 99 had 0 zeroed genomes
# Did not find solution in 100 iterations
# Species:, 5

# %%
top5 = sorted(p.organisms, key=lambda x:x.fitness, reverse=True)[:5]
for o in top5:
    o.show()
    print(o)
    # !open example.html

total_conns = 0
total_nodes = 0
for x in p.organisms:
    total_conns += len(x.connections)
    total_nodes += len(x.nodes)

average_nodes = total_nodes/len(p.organisms)
average_conns = total_conns/len(p.organisms)
print("average nodes: ", average_nodes )
print("average connections: ",total_conns/len(p.organisms))
# Out:
# example.html
# Genome f:$6.25, nodes:3, conns:2
# example.html
# Genome f:$6.25, nodes:3, conns:2
# example.html
# Genome f:$6.25, nodes:3, conns:2
# example.html
# Genome f:$6.25, nodes:3, conns:2
# example.html
# Genome f:$6.25, nodes:3, conns:2
# average nodes:  5.04
# average connections:  6.38

# %%
bigger = [x for x in p.organisms if len(x.connections) > average_conns or len(x.nodes) > average_nodes]
for b in bigger:
    print(b)
    b.show()
    # !open example.html
# Out:
# Genome f:$6.24, nodes:6, conns:9
# example.html
# Genome f:$6.24, nodes:5, conns:7
# example.html
# Genome f:$6.24, nodes:5, conns:7
# example.html
# Genome f:$6.24, nodes:5, conns:7
# example.html
# Genome f:$6.24, nodes:5, conns:7
# example.html
# Genome f:$4.29, nodes:5, conns:7
# example.html
# Genome f:$4.29, nodes:5, conns:7
# example.html
# Genome f:$4.29, nodes:5, conns:7
# example.html
# Genome f:$4.29, nodes:6, conns:9
# example.html
# Genome f:$4.29, nodes:5, conns:7
# example.html
# Genome f:$4.29, nodes:5, conns:7
# example.html
# Genome f:$4.29, nodes:5, conns:7
# example.html
# Genome f:$4.29, nodes:5, conns:7
# example.html
# Genome f:$4.29, nodes:5, conns:8
# example.html
# Genome f:$4.29, nodes:5, conns:7
# example.html
# Genome f:$4.29, nodes:5, conns:7
# example.html
# Genome f:$4.29, nodes:5, conns:7
# example.html
# Genome f:$4.29, nodes:5, conns:7
# example.html
# Genome f:$4.29, nodes:5, conns:7
# example.html
# Genome f:$4.29, nodes:5, conns:7
# example.html
# Genome f:$4.29, nodes:5, conns:7
# example.html
# Genome f:$4.29, nodes:5, conns:7
# example.html
# Genome f:$4.29, nodes:5, conns:7
# example.html
# Genome f:$4.29, nodes:5, conns:7
# example.html
# Genome f:$4.29, nodes:5, conns:7
# example.html
# Genome f:$4.29, nodes:5, conns:7
# example.html
# Genome f:$4.29, nodes:5, conns:7
# example.html
# Genome f:$4.29, nodes:5, conns:7
# example.html
# Genome f:$4.29, nodes:5, conns:7
# example.html
# Genome f:$4.29, nodes:5, conns:7
# example.html
# Genome f:$4.29, nodes:5, conns:7
# example.html
# Genome f:$4.29, nodes:5, conns:7
# example.html
# Genome f:$4.29, nodes:5, conns:7
# example.html

# %%
for o in p.species[-1].organisms: print(o.fitness, o.adjusted_fitness)
# Out:
# 4.0 4.0
# 4.0 4.0
# 4.0 4.0
# 4.0 4.0
# 4.0 4.0
# 4.0 4.0
# 4.0 4.0
# 4.0 4.0
# 4.0 4.0
# 4.0 4.0
# 4.0 4.0
# 4.0 4.0
# 4.0 4.0
# 4.0 4.0
# 4.0 4.0
# 4.0 4.0
# 4.0 4.0
# 4.0 4.0
# 4.0 4.0
# 4.0 4.0
# 4.0 4.0
# 4.0 4.0
# 4.0 4.0
# 4.0 4.0
# 4.0 4.0
# 4.0 4.0
# 4.0 4.0
# 4.0 4.0
# 4.0 4.0

# %%
p.speciate()

# %%
for o in p.species[1].organisms:
    o.show()
    # !open example.html
# Out:
# example.html
# example.html
# example.html
# example.html
# example.html
# example.html
# example.html
# example.html
# example.html
# example.html
# example.html
# example.html
# example.html
# example.html
# example.html
# example.html
# example.html
# example.html
# example.html

# %%
[s for s in p.species if len([b for b in bigger if b in s.organisms]) > 0]
# Out:
# []

# %%
p.speciate()

# %%
Connection.innov_table
# Out:
# {(0, 2): 0,
#  (1, 2): 1,
#  (1, 3): 2,
#  (3, 2): 3,
#  (0, 3): 4,
#  (0, 4): 5,
#  (4, 2): 6,
#  (1, 4): 7,
#  (4, 3): 8,
#  (3, 4): 9,
#  (3, 5): 10,
#  (5, 2): 11,
#  (4, 5): 12,
#  (5, 3): 13,
#  (0, 6): 14,
#  (6, 4): 15,
#  (1, 5): 16,
#  (3, 6): 17,
#  (6, 5): 18,
#  (5, 6): 19,
#  (6, 2): 20,
#  (0, 5): 21,
#  (4, 6): 22,
#  (6, 3): 23,
#  (1, 6): 24,
#  (5, 4): 25,
#  (1, 7): 26,
#  (7, 2): 27,
#  (7, 3): 28,
#  (3, 7): 29,
#  (7, 5): 30,
#  (0, 7): 31,
#  (7, 4): 32,
#  (0, 8): 33,
#  (8, 7): 34,
#  (7, 6): 35,
#  (5, 8): 36,
#  (8, 2): 37,
#  (7, 8): 38,
#  (4, 7): 39,
#  (4, 8): 40,
#  (1, 9): 41,
#  (9, 5): 42,
#  (6, 9): 43,
#  (4, 10): 44,
#  (10, 3): 45,
#  (6, 10): 46,
#  (10, 9): 47,
#  (0, 9): 48,
#  (5, 7): 49,
#  (6, 7): 50,
#  (8, 3): 51,
#  (1, 8): 52,
#  (8, 4): 53,
#  (8, 6): 54,
#  (6, 8): 55,
#  (8, 5): 56,
#  (3, 8): 57,
#  (3, 9): 58,
#  (9, 2): 59,
#  (9, 7): 60,
#  (4, 9): 61,
#  (9, 3): 62,
#  (9, 4): 63,
#  (7, 9): 64}

# %%
Specie.threshold
# Out:
# 3

# %%
p.organisms[0].show()
# !open example.html
# Out:
# example.html

# %%
[o.connections for o in p.organisms]
# Out:
# [[Conn $0, [0 -> 2] enabled, Conn $1, [1 -> 2] enabled],
#  [Conn $0, [0 -> 2] enabled, Conn $1, [1 -> 2] enabled],
#  [Conn $0, [0 -> 2] enabled, Conn $1, [1 -> 2] enabled],
#  [Conn $0, [0 -> 2] enabled, Conn $1, [1 -> 2] enabled],
#  [Conn $0, [0 -> 2] enabled, Conn $1, [1 -> 2] enabled],
#  [Conn $0, [0 -> 2] enabled, Conn $1, [1 -> 2] enabled],
#  [Conn $0, [0 -> 2] enabled,
#   Conn $1, [1 -> 2] disabled,
#   Conn $2, [1 -> 3] enabled,
#   Conn $3, [3 -> 2] enabled],
#  [Conn $0, [0 -> 2] enabled, Conn $1, [1 -> 2] enabled],
#  [Conn $0, [0 -> 2] enabled, Conn $1, [1 -> 2] enabled],
#  [Conn $0, [0 -> 2] enabled, Conn $1, [1 -> 2] enabled],
#  [Conn $0, [0 -> 2] enabled, Conn $1, [1 -> 2] enabled],
#  [Conn $0, [0 -> 2] enabled, Conn $1, [1 -> 2] enabled],
#  [Conn $0, [0 -> 2] enabled, Conn $1, [1 -> 2] enabled],
#  [Conn $0, [0 -> 2] enabled, Conn $1, [1 -> 2] enabled],
#  [Conn $0, [0 -> 2] enabled, Conn $1, [1 -> 2] enabled],
#  [Conn $0, [0 -> 2] enabled,
#   Conn $1, [1 -> 2] enabled,
#   Conn $4, [0 -> 3] enabled,
#   Conn $3, [3 -> 2] enabled,
#   Conn $2, [1 -> 3] disabled,
#   Conn $9, [1 -> 4] disabled,
#   Conn $8, [4 -> 3] enabled,
#   Conn $12, [1 -> 5] enabled,
#   Conn $15, [5 -> 4] enabled],
#  [Conn $0, [0 -> 2] enabled,
#   Conn $1, [1 -> 2] enabled,
#   Conn $4, [0 -> 3] enabled,
#   Conn $3, [3 -> 2] enabled,
#   Conn $2, [1 -> 3] disabled,
#   Conn $9, [1 -> 4] enabled,
#   Conn $8, [4 -> 3] enabled],
#  [Conn $0, [0 -> 2] enabled,
#   Conn $1, [1 -> 2] enabled,
#   Conn $4, [0 -> 3] enabled,
#   Conn $3, [3 -> 2] enabled,
#   Conn $2, [1 -> 3] disabled,
#   Conn $9, [1 -> 4] enabled,
#   Conn $8, [4 -> 3] enabled],
#  [Conn $0, [0 -> 2] enabled,
#   Conn $1, [1 -> 2] enabled,
#   Conn $4, [0 -> 3] enabled,
#   Conn $3, [3 -> 2] enabled,
#   Conn $2, [1 -> 3] disabled,
#   Conn $9, [1 -> 4] enabled,
#   Conn $8, [4 -> 3] enabled],
#  [Conn $0, [0 -> 2] enabled,
#   Conn $1, [1 -> 2] enabled,
#   Conn $4, [0 -> 3] enabled,
#   Conn $3, [3 -> 2] enabled,
#   Conn $2, [1 -> 3] disabled,
#   Conn $9, [1 -> 4] enabled,
#   Conn $8, [4 -> 3] enabled],
#  [Conn $0, [0 -> 2] enabled,
#   Conn $1, [1 -> 2] disabled,
#   Conn $2, [1 -> 3] enabled,
#   Conn $3, [3 -> 2] enabled],
#  [Conn $0, [0 -> 2] enabled,
#   Conn $1, [1 -> 2] disabled,
#   Conn $2, [1 -> 3] enabled,
#   Conn $3, [3 -> 2] enabled],
#  [Conn $0, [0 -> 2] disabled,
#   Conn $1, [1 -> 2] disabled,
#   Conn $2, [1 -> 3] enabled,
#   Conn $3, [3 -> 2] enabled,
#   Conn $7, [0 -> 4] enabled,
#   Conn $6, [4 -> 2] enabled,
#   Conn $4, [0 -> 3] enabled],
#  [Conn $0, [0 -> 2] disabled,
#   Conn $1, [1 -> 2] disabled,
#   Conn $2, [1 -> 3] enabled,
#   Conn $3, [3 -> 2] enabled,
#   Conn $7, [0 -> 4] enabled,
#   Conn $6, [4 -> 2] enabled,
#   Conn $4, [0 -> 3] enabled],
#  [Conn $0, [0 -> 2] disabled,
#   Conn $1, [1 -> 2] disabled,
#   Conn $2, [1 -> 3] enabled,
#   Conn $3, [3 -> 2] enabled,
#   Conn $7, [0 -> 4] enabled,
#   Conn $6, [4 -> 2] enabled,
#   Conn $4, [0 -> 3] enabled],
#  [Conn $0, [0 -> 2] disabled,
#   Conn $1, [1 -> 2] disabled,
#   Conn $2, [1 -> 3] enabled,
#   Conn $3, [3 -> 2] enabled,
#   Conn $7, [0 -> 4] enabled,
#   Conn $6, [4 -> 2] disabled,
#   Conn $4, [0 -> 3] enabled,
#   Conn $10, [4 -> 5] enabled,
#   Conn $13, [5 -> 2] enabled],
#  [Conn $0, [0 -> 2] disabled,
#   Conn $1, [1 -> 2] disabled,
#   Conn $2, [1 -> 3] enabled,
#   Conn $3, [3 -> 2] enabled,
#   Conn $7, [0 -> 4] enabled,
#   Conn $6, [4 -> 2] enabled,
#   Conn $4, [0 -> 3] enabled],
#  [Conn $0, [0 -> 2] disabled,
#   Conn $1, [1 -> 2] disabled,
#   Conn $2, [1 -> 3] enabled,
#   Conn $3, [3 -> 2] enabled,
#   Conn $7, [0 -> 4] enabled,
#   Conn $6, [4 -> 2] enabled,
#   Conn $4, [0 -> 3] enabled],
#  [Conn $0, [0 -> 2] disabled,
#   Conn $1, [1 -> 2] disabled,
#   Conn $2, [1 -> 3] enabled,
#   Conn $3, [3 -> 2] enabled,
#   Conn $7, [0 -> 4] enabled,
#   Conn $6, [4 -> 2] enabled,
#   Conn $4, [0 -> 3] enabled],
#  [Conn $0, [0 -> 2] disabled,
#   Conn $1, [1 -> 2] disabled,
#   Conn $2, [1 -> 3] enabled,
#   Conn $3, [3 -> 2] enabled,
#   Conn $7, [0 -> 4] enabled,
#   Conn $6, [4 -> 2] enabled,
#   Conn $4, [0 -> 3] enabled],
#  [Conn $0, [0 -> 2] disabled,
#   Conn $1, [1 -> 2] disabled,
#   Conn $2, [1 -> 3] enabled,
#   Conn $3, [3 -> 2] enabled,
#   Conn $7, [0 -> 4] enabled,
#   Conn $6, [4 -> 2] enabled,
#   Conn $4, [0 -> 3] enabled,
#   Conn $9, [1 -> 4] enabled],
#  [Conn $0, [0 -> 2] disabled,
#   Conn $1, [1 -> 2] disabled,
#   Conn $2, [1 -> 3] enabled,
#   Conn $3, [3 -> 2] enabled,
#   Conn $7, [0 -> 4] enabled,
#   Conn $6, [4 -> 2] enabled,
#   Conn $4, [0 -> 3] enabled],
#  [Conn $0, [0 -> 2] disabled,
#   Conn $1, [1 -> 2] disabled,
#   Conn $2, [1 -> 3] enabled,
#   Conn $3, [3 -> 2] enabled,
#   Conn $7, [0 -> 4] enabled,
#   Conn $6, [4 -> 2] enabled,
#   Conn $4, [0 -> 3] enabled],
#  [Conn $0, [0 -> 2] disabled,
#   Conn $1, [1 -> 2] disabled,
#   Conn $2, [1 -> 3] enabled,
#   Conn $3, [3 -> 2] enabled,
#   Conn $7, [0 -> 4] enabled,
#   Conn $6, [4 -> 2] enabled,
#   Conn $4, [0 -> 3] enabled],
#  [Conn $0, [0 -> 2] disabled,
#   Conn $1, [1 -> 2] disabled,
#   Conn $2, [1 -> 3] enabled,
#   Conn $3, [3 -> 2] enabled,
#   Conn $7, [0 -> 4] enabled,
#   Conn $6, [4 -> 2] enabled,
#   Conn $4, [0 -> 3] enabled],
#  [Conn $0, [0 -> 2] disabled,
#   Conn $1, [1 -> 2] disabled,
#   Conn $2, [1 -> 3] enabled,
#   Conn $3, [3 -> 2] enabled,
#   Conn $7, [0 -> 4] enabled,
#   Conn $6, [4 -> 2] enabled,
#   Conn $4, [0 -> 3] enabled],
#  [Conn $0, [0 -> 2] disabled,
#   Conn $1, [1 -> 2] disabled,
#   Conn $2, [1 -> 3] enabled,
#   Conn $3, [3 -> 2] enabled,
#   Conn $7, [0 -> 4] enabled,
#   Conn $6, [4 -> 2] enabled,
#   Conn $4, [0 -> 3] enabled],
#  [Conn $0, [0 -> 2] disabled,
#   Conn $1, [1 -> 2] disabled,
#   Conn $2, [1 -> 3] enabled,
#   Conn $3, [3 -> 2] enabled,
#   Conn $7, [0 -> 4] enabled,
#   Conn $6, [4 -> 2] enabled,
#   Conn $4, [0 -> 3] enabled],
#  [Conn $0, [0 -> 2] disabled,
#   Conn $1, [1 -> 2] disabled,
#   Conn $2, [1 -> 3] enabled,
#   Conn $3, [3 -> 2] enabled,
#   Conn $7, [0 -> 4] enabled,
#   Conn $6, [4 -> 2] enabled,
#   Conn $4, [0 -> 3] enabled],
#  [Conn $0, [0 -> 2] disabled,
#   Conn $1, [1 -> 2] disabled,
#   Conn $2, [1 -> 3] enabled,
#   Conn $3, [3 -> 2] enabled,
#   Conn $7, [0 -> 4] enabled,
#   Conn $6, [4 -> 2] enabled,
#   Conn $4, [0 -> 3] enabled],
#  [Conn $0, [0 -> 2] disabled,
#   Conn $1, [1 -> 2] disabled,
#   Conn $2, [1 -> 3] enabled,
#   Conn $3, [3 -> 2] enabled,
#   Conn $7, [0 -> 4] enabled,
#   Conn $6, [4 -> 2] enabled,
#   Conn $4, [0 -> 3] enabled],
#  [Conn $0, [0 -> 2] disabled,
#   Conn $1, [1 -> 2] disabled,
#   Conn $2, [1 -> 3] enabled,
#   Conn $3, [3 -> 2] enabled,
#   Conn $7, [0 -> 4] enabled,
#   Conn $6, [4 -> 2] enabled,
#   Conn $4, [0 -> 3] enabled],
#  [Conn $0, [0 -> 2] disabled,
#   Conn $1, [1 -> 2] disabled,
#   Conn $2, [1 -> 3] enabled,
#   Conn $3, [3 -> 2] enabled,
#   Conn $7, [0 -> 4] enabled,
#   Conn $6, [4 -> 2] enabled,
#   Conn $4, [0 -> 3] enabled],
#  [Conn $0, [0 -> 2] disabled,
#   Conn $1, [1 -> 2] disabled,
#   Conn $2, [1 -> 3] enabled,
#   Conn $3, [3 -> 2] enabled,
#   Conn $7, [0 -> 4] enabled,
#   Conn $6, [4 -> 2] enabled,
#   Conn $4, [0 -> 3] enabled],
#  [Conn $0, [0 -> 2] disabled,
#   Conn $1, [1 -> 2] disabled,
#   Conn $2, [1 -> 3] enabled,
#   Conn $3, [3 -> 2] enabled,
#   Conn $7, [0 -> 4] enabled,
#   Conn $6, [4 -> 2] enabled,
#   Conn $4, [0 -> 3] enabled],
#  [Conn $0, [0 -> 2] disabled,
#   Conn $1, [1 -> 2] disabled,
#   Conn $2, [1 -> 3] enabled,
#   Conn $3, [3 -> 2] enabled,
#   Conn $7, [0 -> 4] enabled,
#   Conn $6, [4 -> 2] enabled,
#   Conn $4, [0 -> 3] enabled],
#  [Conn $0, [0 -> 2] disabled,
#   Conn $1, [1 -> 2] disabled,
#   Conn $2, [1 -> 3] enabled,
#   Conn $3, [3 -> 2] enabled,
#   Conn $7, [0 -> 4] enabled,
#   Conn $6, [4 -> 2] enabled,
#   Conn $4, [0 -> 3] enabled],
#  [Conn $0, [0 -> 2] disabled,
#   Conn $1, [1 -> 2] disabled,
#   Conn $2, [1 -> 3] enabled,
#   Conn $3, [3 -> 2] enabled,
#   Conn $7, [0 -> 4] enabled,
#   Conn $6, [4 -> 2] enabled,
#   Conn $4, [0 -> 3] enabled],
#  [Conn $0, [0 -> 2] disabled,
#   Conn $1, [1 -> 2] disabled,
#   Conn $2, [1 -> 3] enabled,
#   Conn $3, [3 -> 2] enabled,
#   Conn $7, [0 -> 4] enabled,
#   Conn $6, [4 -> 2] enabled,
#   Conn $4, [0 -> 3] enabled],
#  [Conn $0, [0 -> 2] disabled,
#   Conn $1, [1 -> 2] disabled,
#   Conn $2, [1 -> 3] enabled,
#   Conn $3, [3 -> 2] enabled,
#   Conn $7, [0 -> 4] enabled,
#   Conn $6, [4 -> 2] enabled,
#   Conn $4, [0 -> 3] enabled]]

# %%
g = Genome(2,1)
g.show()
# !open example.html
# Out:
# example.html

# %%
g.mutate()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /Users/polya/workshop/playgrounds/NEAT_playground/nano_neat/toplevel.ipynb Cell 7 line 1
# ----> <a href='vscode-notebook-cell:/Users/polya/workshop/playgrounds/NEAT_playground/nano_neat/toplevel.ipynb#X53sZmlsZQ%3D%3D?line=0'>1</a> g.mutate()
#
# NameError: name 'g' is not defined

# %%
g.show()
# !open example.html
# Out:
# example.html

# %%
g.mutate_add_node()

# %% [markdown]
# # Prev idea
# I'm gonna combine two ideas:
# - only top 20% from every species can reproduce
# - crossover can happen between any two genomes, although weights inside species are boosted
#
# First idea ok, second is dogshit
#
# # Current state of affairs:
# i can generate a bunch of networks that look like they could work, but for some reason the basic network always gets more fitness than them :// idk why. Also they can't evolve past 6.25?

# %%
# Out:
# [Conn $0, [0 -> 2] enabled,
#  Conn $1, [1 -> 2] disabled,
#  Conn $2, [1 -> 3] enabled,
#  Conn $3, [1 -> 3] enabled]
