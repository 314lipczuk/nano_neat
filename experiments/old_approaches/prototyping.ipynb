# %%
# New approach
import typing
import copy
import math
import random
import pyvis
import networkx as nx
from pyvis.network import Network as VisualNetwork
"""
XOR using neat
"""

""" 
    1) dokończyć swoją implementację
    2) gymnasium + NEAT
    3) zastąpić sumowanie filtrem kalmana
"""

"""
Looking at YT Neat AI channel.
Wnioski:
- Moje rozmnazanie nie jest dobre. Trzeba zrobić to tak jak w filmiku.
-PLAYLIST: 
https://www.youtube.com/watch?v=3nbvrrdymF0&list=PLnICFpQDyZRFqjdtcTjshOb1IJqns6h6w

Mozna podzielic na warstwy, po najdluzszyeh sciezce do inputu. Dzieki temu mozna latwo rysowac i latwo ewaluowac w forward passie
"""

# activation function on every eval step?
# Okej. Rzeczy nie działają. Tak bywa. Następne kroki:
# 1) Przerobić całkowicie / audytować model dodawania numerów innowacji i id_node
# Jak trzeba wyrywać kawałki kodu z korzeniami to chuj. Trzeba.
import random
"""
n = 5; avg F = 6 -> 5
n = 8 avg f = 7.9 -> 9
n = 2 avg f = 5 -> 1
global avg = 6.9
(avg f / global avg) X N


speciation -> crossover -> mutation

todo:
- global innovation number table
- species : generations since last progress

"""
def relu(x):
    if x > 0:
        return x
    else:
        return 0

def sigm(x):
    return 1 / (1 + math.exp(-x))

LOGS = {"WEIGHT_MUTATION":0, "NEW_CONNECTION":0, "NEW_NODE":0, "CROSSOVER":0, "SPECIES":0}

def restart_logs():
    global LOGS
    for x in LOGS:
        LOGS[x] = 0

WEIGHT_MUTATION_CHANCE = 0.8
NEW_CONNECTION_CHANCE = 0.1
NEW_NODE_CHANCE = 0.05
ACTIVATION_FUNC = sigm
C1 = 1.0
C2 = 1.0
C3 = 0.4
SPECIES_THRESHOLD = 3 # Threshold for determining if two genomes belong to the same species

TO_DEBUG = None

# %%
class Node:
    def __init__(self, node_id, node_type='hidden'):
        self.node_id = node_id
        self.node_type = node_type  #  'input' | 'hidden' | 'output'

    def __repr__(self):
        return f"{self.node_type} Node {self.node_id} "
    
    def __hash__(self):
        return hash((self.node_id, self.node_type))

    def __eq__(self, other):
        if isinstance(other, Node):
            return self.node_id == other.node_id and self.node_type == other.node_type
        return False

class Connection:
    def __init__(self, in_node, out_node, weight=1.0, enabled=True, innov_number=None):
        self.in_node = in_node
        self.out_node = out_node
        self.weight = weight
        self.enabled = enabled
        self.innov_number = innov_number  # crossover

    def __repr__(self):
        return f"Conn from {self.in_node} to {self.out_node}, weight:{self.weight}, en:{self.enabled}, innv:{self.innov_number}"

# %%
class Genome:
    def __init__(self):
        self.nodes = []
        self.connections = []
        self.fitness = 0
   
    def __repr__(self):
        return f"Genome with {len(self.nodes)} nodes and {len(self.connections)} connections. Fitness: {self.fitness}"
    
    def set_manager(self, manager):
        self.manager = manager

    def copy(self):
        newg = copy.copy(self)
        newg.nodes = copy.deepcopy(self.nodes)
        newg.connections= copy.deepcopy(self.connections)
        return newg

    @staticmethod
    def construct_from_dict(nodes:dict[int, Node], connections:dict[int,Connection]):
        "Does not change global innov_number and node_id"
        g = Genome()
        for (i,n) in sorted(nodes.items()):
            if n.node_id is None:
                n.node_id = i
            g.nodes.append(n)
        
        for (i,c) in sorted(connections.items()):
            if c.innov_number is None:
                c.innov_number = i
            g.connections.append(c)
        return g
    

    def set_fitness(self, new):
        self.fitness = new

    @staticmethod
    def create_from_shape(shape:tuple[int,int]):
        inputs,outputs = shape
        g = Genome()

        for i in range(inputs):
            g.add_node('input')

        for o in range(outputs):
            g.add_node('output')

        ins = list(filter(lambda x:x.node_type == 'input', g.nodes))
        outs = list(filter(lambda x:x.node_type == 'output', g.nodes))
        for i in ins:
            for o in outs:
                g.add_connection(i.node_id, o.node_id, 1.0)
        return g

    def add_node(self, node_type):
        node_id = self.manager.get_next_node_id()
        node = Node(node_id, node_type)
        self.nodes.append(node)
        return node

    def evaluate(self, input):
        ff_in = {}
        for (i, n) in enumerate(input):
            ff_in[i] = n
        return feed_forward(self, ff_in, ACTIVATION_FUNC)

    def add_connection(self, in_node, out_node, weight, mark=None):
        innov_number = self.manager.get_next_innov_number()
        connection = Connection(in_node, out_node, weight, innov_number)
        if mark is not None:
            connection.mark = mark
        self.connections.append(connection)
    
    def show(self):
        graph = nx.Graph()
        nt = VisualNetwork(notebook=True , cdn_resources='in_line',layout=True, directed=True)
        for n in self.nodes:nt.add_node(
            n.node_id,
            label=f"{n.node_type},{n.node_id}",
            level = 6 if n.node_type == 'input' else 0 if n.node_type == 'output' else random.randint(1,5),
            )
        for c in self.connections:
            nt.add_edge(source=c.in_node,to=c.out_node, title=f"in:{c.innov_number}\nw:{c.weight}", hidden=(not c.enabled) )
        nt.from_nx(graph) 

        nt.show('example.html')
        # !open "example.html"

    def mutate(self):
        for connection in self.connections:
            if random.random() < WEIGHT_MUTATION_CHANCE:
                print("WEIGHT_MUTATION")
                LOGS["WEIGHT_MUTATION"] += 1
                connection.weight += random.uniform(-1, 1) 

        if random.random() < NEW_CONNECTION_CHANCE:
            node1 = random.choice(self.nodes)
            node2 = random.choice(self.nodes)
            if node1.node_type != 'output' and\
                node2.node_type != 'input' and\
                node1.node_id != node2.node_id and\
                not any([c for c in self.connections if ((c.in_node == node1.node_id and c.out_node == node2.node_id and c.enabled) or (c.in_node == node2.node_id and c.out_node == node1.node_id and c.enabled)) ]):

                print(f"NEW CONNECTION {node1.node_id} -> {node2.node_id}")
                LOGS["NEW_CONNECTION"] += 1
                self.add_connection(node1.node_id, node2.node_id, random.uniform(-1, 1))

        if random.random() < NEW_NODE_CHANCE:
            connection = random.choice(self.connections)
            connection.enabled = False
            print("NEW NODE")
            LOGS["NEW_NODE"] += 1
            new_node = self.add_node('hidden')
            self.add_connection(connection.in_node, new_node.node_id, 1.0, mark=f"NNC1 {connection} gen:{self.manager.generation}")
            self.add_connection(new_node.node_id, connection.out_node, connection.weight, mark=f"NNC2 {connection} gen:{self.manager.generation}")

    def compatibility_distance(self, other_genome):
        matching_weight_diffs = []
        disjoint_count = 0
        excess_count = 0

        self_genes = {c.innov_number: c for c in self.connections}
        other_genes = {c.innov_number: c for c in other_genome.connections}

        for innov in set(self_genes.keys()).union(other_genes.keys()):
            if innov in self_genes and innov in other_genes:
                matching_weight_diffs.append(abs(self_genes[innov].weight - other_genes[innov].weight))
            elif innov in self_genes:
                if innov > max(other_genes.keys()):
                    excess_count += 1
                else:
                    disjoint_count += 1
            elif innov in other_genes:
                if innov > max(self_genes.keys()):
                    excess_count += 1
                else:
                    disjoint_count += 1

        avg_weight_diff = sum(matching_weight_diffs) / len(matching_weight_diffs) if matching_weight_diffs else 0.0
        N = max(len(self.connections), len(other_genome.connections))
        N = max(N, 1)

        distance = (C1 * disjoint_count + C2 * excess_count) / N + C3 * avg_weight_diff
        return distance

# %%
def crossover(genome1:Genome, genome2:Genome):

    def equals(g1, g2):
        return abs(g1.fitness - g2.fitness) < 0.01

    def calculate_weight_for_common(g1:Connection, g2:Connection, method='avg'):
        "Return either function for averaging weights or picking one randomly from genomes"
        assert (method == 'avg' or method=='rand')
        if method == 'avg':
            return (g1.weight + g2.weight ) / 2
        else:
            return g1.weight if random.random() > 0.5 else g2.weight

    gene_comparison = {}
    if genome2.fitness > genome1.fitness:
        tmp = genome1
        genome1 = genome2
        genome2 = tmp
    for (conn, fromGene) in list(zip(genome1.connections, len(genome1.connections)*[0])) + list(zip(genome2.connections, len(genome2.connections) * [1])):
        present = gene_comparison.get(conn.innov_number)
        if present is not None:
            present[fromGene] = conn
        else:
            gene_comparison[conn.innov_number] = { fromGene : conn } 

    are_equal = equals(genome1, genome2)
    sorted_keys = sorted(gene_comparison.keys())
    product = []
    highest_innov_for_shorter_parent = min([ max([g.innov_number for g in genome1.connections]), max([g.innov_number for g in genome2.connections]) ])
    for gene_i in sorted_keys:
        pair = gene_comparison[gene_i]
        g0, g1 = pair.get(0), pair.get(1)
        if g0 is not None and g1 is not None and g0.innov_number == g1.innov_number:
            tmp = copy.deepcopy(g0)
            tmp.weight = calculate_weight_for_common(g0, g1)
            product.append(tmp)
            continue
        if are_equal:
            assert are_equal, "Fitness of both genomes is equal, picking genes at random"
            if g0 is None or g1 is None:
                present = g0 or g1
                if present.innov_number > highest_innov_for_shorter_parent:
                    "Excess"
                    if random.random() > 0.5:
                        "equal - get inherited by random parent"
                        product.append(copy.deepcopy(present))
                        # not equal
                else:
                    assert (not (g1 is not None and g0 is not None)), "Disjoint, collect at random"
                    choice = pair.get(round(random.random())) # 0 or 1
                    if choice is not None:
                        product.append(copy.deepcopy(choice))
        else:
            assert not are_equal, "Fitness of both genomes is not equal, picking only options from best one"
            if g0 is not None:
                product.append(copy.deepcopy(g0))
                #disjoint - gets inherited from fitter parent, or from random if they're equal
    # ok, lecimy: Node'y
    ins_and_outs = set()
    for c in product:
        ins_and_outs.add(c.in_node)
        ins_and_outs.add(c.out_node)
    nodes = list(filter(lambda n: n.node_id in ins_and_outs, set(genome1.nodes).union(set(genome2.nodes))))
    ret = Genome.construct_from_dict(nodes={n.node_id:n for n in nodes}, connections={ p.innov_number:p for p in product})
    print("CROSSOVER")
    LOGS["CROSSOVER"] += 1
    #ret.parents = [genome1, genome2]
    return ret

# %%
class Species:
    def __init__(self, representative):
        self.members = [representative]
        self.representative = representative

    def add_member(self, genome):
        self.members.append(genome)

    def clear_members(self):
        self.members = []

    def adjust_fitnesses(self):
        total_fitness = sum([genome.fitness for genome in self.members])
        for genome in self.members:
            genome.fitness /= total_fitness

    def set_representative(self):
        self.representative = random.choice(self.members)


def speciate(genomes, species):
    for spec in species:
        spec.clear_members()

    for genome in genomes:
        found_species = False
        for spec in species:
            if genome.compatibility_distance(spec.representative) < SPECIES_THRESHOLD:
                spec.add_member(genome)
                found_species = True
                LOGS["SPECIES"] += 1
                break
        if not found_species:
            new_species = Species(genome)
            species.append(new_species)

    # Remove empty species
    species = [spec for spec in species if spec.members]

    return species

# %%
import numpy as np
def feed_forward(genome:Genome, input_values:dict[int,float], activation_func):
    try:
        DEFAULT_BIAS_VALUE = 1.0
        """
        O boze o kurwa
        To moze mieć rekurencyjne połączenia
        TODO zaimplementować to.
        """
        all_output_nodes = set([n for n in genome.nodes if n.node_type == 'output'])
        valid_connections = [ c for c in genome.connections if c.enabled] 
        dependency_tree = {}
        values = input_values 
        all_output_nodes = set([n for n in genome.nodes if n.node_type == 'output'])
        # allow for biases to appear (if node is not input and has no incoming connections)
        values.update({n.node_id: DEFAULT_BIAS_VALUE for n in genome.nodes if n.node_type == 'hidden' and not any([c.out_node == n.node_id for c in valid_connections])})
        for c in valid_connections:
            if dependency_tree.get(c.out_node) is not None:
                dependency_tree[c.out_node].add(c)
            else:
                dependency_tree[c.out_node] = set([c])

        def eval_node(node_id):
            if(values.get(node_id) is not None):
                return values.get(node_id)
            else:
                deps = []
                dependants = dependency_tree.get(node_id)
                for conn in dependants:
                    deps.append(eval_node(conn.in_node) * conn.weight)
                v = activation_func(sum(deps))
                values[node_id] = v
                return v
        final = [eval_node(o.node_id) for o in all_output_nodes]
        if len(final) == 0:
            print(f"genome: {genome} ")
            #genome.show()
            return final
        else:
            return final
    except Exception as e:
        global TO_DEBUG
        TO_DEBUG = genome
        raise e

# %%
TO_DEBUG.connections
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# /Users/polya/workshop/playgrounds/NEAT_playground/nano_neat/prototyping.ipynb Cell 7 line 1
# ----> <a href='vscode-notebook-cell:/Users/polya/workshop/playgrounds/NEAT_playground/nano_neat/prototyping.ipynb#W6sZmlsZQ%3D%3D?line=0'>1</a> TO_DEBUG.connections
#
# AttributeError: 'NoneType' object has no attribute 'connections'

# %%
INPUT = [[0,0], [0,1], [1,0], [1,1]]
OUTPUT = [0, 1, 1, 0]
import copy
def eval(genome):
    """
    Evaluation function as specified in the paper. TODO: research why exactly is it like that.
    """
    #result = [feed_forward(genome, input_values= dict(enumerate(iv)), activation_func=ACTIVATION_FUNC)[0] for iv in INPUT]
    result = []
    for i, iv in enumerate(INPUT):
        res= feed_forward(genome, input_values= dict(enumerate(iv)), activation_func=ACTIVATION_FUNC) 
        print(f"input: {iv}, output: {res}, truth: {OUTPUT[i]}")
        result.append(res[0])
    assert(len(OUTPUT) == len(result))
    error = sum([ abs(r - o) for (r,o) in zip(result, OUTPUT)])
    y = (4 - error) ** 2
    return y

# %%
# aight, lets artificially construct the 'good' solution to check if my eval will even work
g1 = Genome.construct_from_dict(
        nodes={
            0:Node(0, 'input'),
            1:Node(1, 'input'),
            2:Node(2, 'output'),
            3:Node(3, 'hidden'),
            4:Node(4, 'hidden'),
        },
        connections={
            0:Connection(in_node=0, out_node=2),
            1:Connection(in_node=1, out_node=2),
            2:Connection(in_node=3, out_node=2),
            3:Connection(in_node=0, out_node=4),
            4:Connection(in_node=1, out_node=4),
            5:Connection(in_node=4, out_node=2),
        }
    )
#g1.show()
eval(g1)
# Out:
# input: [0, 0], output: [0.8175744761936437], truth: 0
# input: [0, 1], output: [0.9388346534008736], truth: 1
# input: [1, 0], output: [0.9388346534008736], truth: 1
# input: [1, 1], output: [0.9797827978364861], truth: 0
# 4.32769815369438

# %%
feed_forward(g1, {0:1, 1:0}, sigm)
# Out:
# genome: Genome with 4 nodes and 6 connections. Fitness: 0
# []

# %%
g1.show()
# Out:
# example.html
# 64494.33s - pydevd: Sending message related to process being replaced timed-out after 5 seconds

# %%
g1.nodes
# Out:
# [input Node 0 , input Node 1 , output Node 2 , hidden Node 3 , hidden Node 4 ]

# %%
g1.show()
# Out:
# example.html
# 65849.30s - pydevd: Sending message related to process being replaced timed-out after 5 seconds

# %%
g1.mutate()
# Out:
# WEIGHT_MUTATION
# WEIGHT_MUTATION
# WEIGHT_MUTATION
# WEIGHT_MUTATION
# WEIGHT_MUTATION

# %%
eval(g1)
# Out:
# input: [0, 0], output: [0.8921564362394694], truth: 0
# input: [0, 1], output: [0.981741088376044], truth: 1
# input: [1, 0], output: [0.9104689601669768], truth: 1
# input: [1, 1], output: [0.9798942442375935], truth: 0
# 4.08104387238465

# %%
candidate = sorted(p.genomes,key=lambda x: x.fitness, reverse=True)[0]
eval(candidate)
candidate.show()
# Out:
# input: [0, 0], output: [0.5], truth: 0
# input: [0, 1], output: [0.6988314359277137], truth: 1
# input: [1, 0], output: [0.6793954573960537], truth: 1
# input: [1, 1], output: [0.83100046650024], truth: 0
# example.html
# 63391.08s - pydevd: Sending message related to process being replaced timed-out after 5 seconds

# %%
class Population:
    """
    Toplevel object
    """
    population = 40
    max_iters = 100
    percentile_best_from_previous_population_to_transfer = 0.1
    percentile_to_reproduce = 0.5
    probability_crossover = 0.3
    probability_mutation_after_crossover = 0.3

    def get_next_innov_number(self):
        self.next_innov_number += 1
        return self.next_innov_number
    def get_next_node_id(self):
        self.node_id+= 1
        return self.node_id

    def __init__(self, starting_genome:Genome, min_success_score=1, evaluation_function=eval):
        self.generation = 0
        self.genomes = []
        starting_genome.set_manager(self)
        self.innov_number = 0
        self.node_id= 0
        starting_genome.fitness = 1
        for r in range(Population.population):
            print('range', r)
            n = starting_genome.copy()
            print('range after copy', r, 'genome:', n)
            for c in n.connections:
                c.weight = random.uniform(-1,1)
            self.genomes.append(n)
        self.species = [Species(self.genomes[0])]
        self.next_innov_number = max([c.innov_number for c in starting_genome.connections]) + 1
        self.next_node_id = max([n.node_id for n in starting_genome.nodes]) + 1
        print(f"Starting Population....  Next innov:{self.next_innov_number}, next node:{self.next_node_id}")

    def get_innov_number(self):
            tmp = self.next_innov_number
            self.next_innov_number += 1
            return tmp

    def get_node_id(self):
            tmp = self.next_node_id
            self.next_node_id += 1
            return tmp

    def show_generation(self):
        #print amount of species, and amount of genomes in each species. print top 5 genomes in each species
        print('#############################################')
        print(f"***Generation {self.generation}***")
        print(f"Species: {len(self.species)}")
        for (i,s) in enumerate(self.species):
            print(f"Species {i} has {len(s.members)} members, top 5 are {sorted(s.members, reverse=True, key=lambda g: g.fitness)[0:5]}")
        print(f"Top 5 genomes are {sorted(self.genomes, reverse=True, key=lambda g: g.fitness)[0:5]}")

    
    def evolve(self) -> list[Genome]:
        distribution = [ sum([g.fitness for g in s.members]) for s in self.species]
        # eliminate lowest performing specimen in each specie
        for s in self.species:
            s.members = sorted(s.members, reverse=True, key=lambda g: g.fitness)[0:max(int(len(s.members) * self.percentile_to_reproduce),1)]

        new_population = [g.copy() for g in self.genomes[0:(int(len(self.genomes) * self.percentile_best_from_previous_population_to_transfer))]]
        while len(new_population) < self.population:
            to_select_for_reproduction = random.choices(self.species, weights=distribution, k=1)[0]
            if random.random() < self.probability_crossover:
                #p1 = random.choice(to_select_for_reproduction.members)
                #p2 = random.choice(self.genomes)
                p1,p2 = random.choices(self.species, weights=distribution, k=2)
                p1= random.choice(p1.members)
                p2= random.choice(p2.members)

                child = crossover(p1, p2)
                if random.random() < self.probability_mutation_after_crossover:
                    child.mutate()
                new_population.append(child)
            else:
                g = (random.choice(to_select_for_reproduction.members)).copy()
                g.mutate()
                new_population.append(g)
        return new_population
    
    def run(self):
        # Create next generation
        self.genomes = self.evolve()
        # Partition new generation into species
        self.species = speciate(self.genomes, self.species)
        # Evaluate fitness
        self.generation += 1
        results = map(eval, self.genomes)
        for (g, v) in zip(self.genomes, results): g.fitness = v 
        #for s in self.species: s.adjust_fitnesses()
        self.genomes = sorted(self.genomes, reverse=True, key=lambda g: g.fitness)
        self.show_generation()
        for s in self.species: s.adjust_fitnesses()
        self.genomes = sorted(self.genomes, reverse=True, key=lambda g: g.fitness)
        # Check criteria

        # if self.min_success_score <= self.genomes[0].fitness:
        #     print("Score threshold exceeded. Finishing...")
        #     return True


    def run_all(self):
        while self.generation < self.max_iters: 
            self.run()

# %%
len(p.species[0].members)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /Users/polya/workshop/playgrounds/NEAT_playground/nano_neat/prototyping.ipynb Cell 19 line 1
# ----> <a href='vscode-notebook-cell:/Users/polya/workshop/playgrounds/NEAT_playground/nano_neat/prototyping.ipynb#X24sZmlsZQ%3D%3D?line=0'>1</a> len(p.species[0].members)
#
# NameError: name 'p' is not defined

# %%
p = Population(g1)
TO_DEBUG = None
restart_logs()
p.run()
# Out:
# range 0
# range after copy 0 genome: Genome with 5 nodes and 6 connections. Fitness: 1
# range 1
# range after copy 1 genome: Genome with 5 nodes and 6 connections. Fitness: 1
# range 2
# range after copy 2 genome: Genome with 5 nodes and 6 connections. Fitness: 1
# range 3
# range after copy 3 genome: Genome with 5 nodes and 6 connections. Fitness: 1
# range 4
# range after copy 4 genome: Genome with 5 nodes and 6 connections. Fitness: 1
# range 5
# range after copy 5 genome: Genome with 5 nodes and 6 connections. Fitness: 1
# range 6
# range after copy 6 genome: Genome with 5 nodes and 6 connections. Fitness: 1
# range 7
# range after copy 7 genome: Genome with 5 nodes and 6 connections. Fitness: 1
# range 8
# range after copy 8 genome: Genome with 5 nodes and 6 connections. Fitness: 1
# range 9
# range after copy 9 genome: Genome with 5 nodes and 6 connections. Fitness: 1
# range 10
# range after copy 10 genome: Genome with 5 nodes and 6 connections. Fitness: 1
# range 11
# range after copy 11 genome: Genome with 5 nodes and 6 connections. Fitness: 1
# range 12
# range after copy 12 genome: Genome with 5 nodes and 6 connections. Fitness: 1
# range 13
# range after copy 13 genome: Genome with 5 nodes and 6 connections. Fitness: 1
# range 14
# range after copy 14 genome: Genome with 5 nodes and 6 connections. Fitness: 1
# range 15
# range after copy 15 genome: Genome with 5 nodes and 6 connections. Fitness: 1
# range 16
# range after copy 16 genome: Genome with 5 nodes and 6 connections. Fitness: 1
# range 17
# range after copy 17 genome: Genome with 5 nodes and 6 connections. Fitness: 1
# range 18
# range after copy 18 genome: Genome with 5 nodes and 6 connections. Fitness: 1
# range 19
# range after copy 19 genome: Genome with 5 nodes and 6 connections. Fitness: 1
# range 20
# range after copy 20 genome: Genome with 5 nodes and 6 connections. Fitness: 1
# range 21
# range after copy 21 genome: Genome with 5 nodes and 6 connections. Fitness: 1
# range 22
# range after copy 22 genome: Genome with 5 nodes and 6 connections. Fitness: 1
# range 23
# range after copy 23 genome: Genome with 5 nodes and 6 connections. Fitness: 1
# range 24
# range after copy 24 genome: Genome with 5 nodes and 6 connections. Fitness: 1
# range 25
# range after copy 25 genome: Genome with 5 nodes and 6 connections. Fitness: 1
# range 26
# range after copy 26 genome: Genome with 5 nodes and 6 connections. Fitness: 1
# range 27
# range after copy 27 genome: Genome with 5 nodes and 6 connections. Fitness: 1
# range 28
# range after copy 28 genome: Genome with 5 nodes and 6 connections. Fitness: 1
# range 29
# range after copy 29 genome: Genome with 5 nodes and 6 connections. Fitness: 1
# range 30
# range after copy 30 genome: Genome with 5 nodes and 6 connections. Fitness: 1
# range 31
# range after copy 31 genome: Genome with 5 nodes and 6 connections. Fitness: 1
# range 32
# range after copy 32 genome: Genome with 5 nodes and 6 connections. Fitness: 1
# range 33
# range after copy 33 genome: Genome with 5 nodes and 6 connections. Fitness: 1
# range 34
# range after copy 34 genome: Genome with 5 nodes and 6 connections. Fitness: 1
# range 35
# range after copy 35 genome: Genome with 5 nodes and 6 connections. Fitness: 1
# range 36
# range after copy 36 genome: Genome with 5 nodes and 6 connections. Fitness: 1
# range 37
# range after copy 37 genome: Genome with 5 nodes and 6 connections. Fitness: 1
# range 38
# range after copy 38 genome: Genome with 5 nodes and 6 connections. Fitness: 1
# range 39
# range after copy 39 genome: Genome with 5 nodes and 6 connections. Fitness: 1
# Starting Population....  Next innov:6, next node:5
# WEIGHT_MUTATION
# WEIGHT_MUTATION
# WEIGHT_MUTATION
# WEIGHT_MUTATION
# WEIGHT_MUTATION
# WEIGHT_MUTATION
# WEIGHT_MUTATION
# WEIGHT_MUTATION
# WEIGHT_MUTATION
# WEIGHT_MUTATION
# WEIGHT_MUTATION
# WEIGHT_MUTATION
# WEIGHT_MUTATION
# WEIGHT_MUTATION
# WEIGHT_MUTATION
# WEIGHT_MUTATION
# WEIGHT_MUTATION
# WEIGHT_MUTATION
# WEIGHT_MUTATION
# CROSSOVER
# WEIGHT_MUTATION
# WEIGHT_MUTATION
# WEIGHT_MUTATION
# WEIGHT_MUTATION
# WEIGHT_MUTATION
# WEIGHT_MUTATION
# WEIGHT_MUTATION
# WEIGHT_MUTATION
# WEIGHT_MUTATION
# WEIGHT_MUTATION
# WEIGHT_MUTATION
# WEIGHT_MUTATION
# WEIGHT_MUTATION
# WEIGHT_MUTATION
# WEIGHT_MUTATION
# WEIGHT_MUTATION
# WEIGHT_MUTATION
# WEIGHT_MUTATION
# WEIGHT_MUTATION
# WEIGHT_MUTATION
# WEIGHT_MUTATION
# WEIGHT_MUTATION
# WEIGHT_MUTATION
# WEIGHT_MUTATION
# WEIGHT_MUTATION
# NEW NODE
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# /Users/polya/workshop/playgrounds/NEAT_playground/nano_neat/prototyping.ipynb Cell 20 line 4
#       <a href='vscode-notebook-cell:/Users/polya/workshop/playgrounds/NEAT_playground/nano_neat/prototyping.ipynb#X25sZmlsZQ%3D%3D?line=1'>2</a> TO_DEBUG = None
#       <a href='vscode-notebook-cell:/Users/polya/workshop/playgrounds/NEAT_playground/nano_neat/prototyping.ipynb#X25sZmlsZQ%3D%3D?line=2'>3</a> restart_logs()
# ----> <a href='vscode-notebook-cell:/Users/polya/workshop/playgrounds/NEAT_playground/nano_neat/prototyping.ipynb#X25sZmlsZQ%3D%3D?line=3'>4</a> p.run()
#
# /Users/polya/workshop/playgrounds/NEAT_playground/nano_neat/prototyping.ipynb Cell 20 line 7
#      <a href='vscode-notebook-cell:/Users/polya/workshop/playgrounds/NEAT_playground/nano_neat/prototyping.ipynb#X25sZmlsZQ%3D%3D?line=73'>74</a> def run(self):
#      <a href='vscode-notebook-cell:/Users/polya/workshop/playgrounds/NEAT_playground/nano_neat/prototyping.ipynb#X25sZmlsZQ%3D%3D?line=74'>75</a>     # Create next generation
# ---> <a href='vscode-notebook-cell:/Users/polya/workshop/playgrounds/NEAT_playground/nano_neat/prototyping.ipynb#X25sZmlsZQ%3D%3D?line=75'>76</a>     self.genomes = self.evolve()
#      <a href='vscode-notebook-cell:/Users/polya/workshop/playgrounds/NEAT_playground/nano_neat/prototyping.ipynb#X25sZmlsZQ%3D%3D?line=76'>77</a>     # Partition new generation into species
#      <a href='vscode-notebook-cell:/Users/polya/workshop/playgrounds/NEAT_playground/nano_neat/prototyping.ipynb#X25sZmlsZQ%3D%3D?line=77'>78</a>     self.species = speciate(self.genomes, self.species)
#
# /Users/polya/workshop/playgrounds/NEAT_playground/nano_neat/prototyping.ipynb Cell 20 line 7
#      <a href='vscode-notebook-cell:/Users/polya/workshop/playgrounds/NEAT_playground/nano_neat/prototyping.ipynb#X25sZmlsZQ%3D%3D?line=67'>68</a>     else:
#      <a href='vscode-notebook-cell:/Users/polya/workshop/playgrounds/NEAT_playground/nano_neat/prototyping.ipynb#X25sZmlsZQ%3D%3D?line=68'>69</a>         g = (random.choice(to_select_for_reproduction.members)).copy()
# ---> <a href='vscode-notebook-cell:/Users/polya/workshop/playgrounds/NEAT_playground/nano_neat/prototyping.ipynb#X25sZmlsZQ%3D%3D?line=69'>70</a>         g.mutate()
#      <a href='vscode-notebook-cell:/Users/polya/workshop/playgrounds/NEAT_playground/nano_neat/prototyping.ipynb#X25sZmlsZQ%3D%3D?line=70'>71</a>         new_population.append(g)
#      <a href='vscode-notebook-cell:/Users/polya/workshop/playgrounds/NEAT_playground/nano_neat/prototyping.ipynb#X25sZmlsZQ%3D%3D?line=71'>72</a> return new_population
#
# /Users/polya/workshop/playgrounds/NEAT_playground/nano_neat/prototyping.ipynb Cell 20 line 1
#     <a href='vscode-notebook-cell:/Users/polya/workshop/playgrounds/NEAT_playground/nano_neat/prototyping.ipynb#X25sZmlsZQ%3D%3D?line=111'>112</a> print("NEW NODE")
#     <a href='vscode-notebook-cell:/Users/polya/workshop/playgrounds/NEAT_playground/nano_neat/prototyping.ipynb#X25sZmlsZQ%3D%3D?line=112'>113</a> LOGS["NEW_NODE"] += 1
# --> <a href='vscode-notebook-cell:/Users/polya/workshop/playgrounds/NEAT_playground/nano_neat/prototyping.ipynb#X25sZmlsZQ%3D%3D?line=113'>114</a> new_node = self.add_node('hidden')
#     <a href='vscode-notebook-cell:/Users/polya/workshop/playgrounds/NEAT_playground/nano_neat/prototyping.ipynb#X25sZmlsZQ%3D%3D?line=114'>115</a> self.add_connection(connection.in_node, new_node.node_id, 1.0, mark=f"NNC1 {connection} gen:{self.manager.generation}")
#     <a href='vscode-notebook-cell:/Users/polya/workshop/playgrounds/NEAT_playground/nano_neat/prototyping.ipynb#X25sZmlsZQ%3D%3D?line=115'>116</a> self.add_connection(new_node.node_id, connection.out_node, connection.weight, mark=f"NNC2 {connection} gen:{self.manager.generation}")
#
# /Users/polya/workshop/playgrounds/NEAT_playground/nano_neat/prototyping.ipynb Cell 20 line 5
#      <a href='vscode-notebook-cell:/Users/polya/workshop/playgrounds/NEAT_playground/nano_neat/prototyping.ipynb#X25sZmlsZQ%3D%3D?line=55'>56</a> def add_node(self, node_type):
# ---> <a href='vscode-notebook-cell:/Users/polya/workshop/playgrounds/NEAT_playground/nano_neat/prototyping.ipynb#X25sZmlsZQ%3D%3D?line=56'>57</a>     node_id = self.manager.get_next_node_id()
#      <a href='vscode-notebook-cell:/Users/polya/workshop/playgrounds/NEAT_playground/nano_neat/prototyping.ipynb#X25sZmlsZQ%3D%3D?line=57'>58</a>     node = Node(node_id, node_type)
#      <a href='vscode-notebook-cell:/Users/polya/workshop/playgrounds/NEAT_playground/nano_neat/prototyping.ipynb#X25sZmlsZQ%3D%3D?line=58'>59</a>     self.nodes.append(node)
#
# AttributeError: 'Population' object has no attribute 'get_next_node_id'

# %%
g1.connections
# Out:
# [Conn from 0 to 2, weight:1.0, en:True, innv:0,
#  Conn from 1 to 2, weight:1.0, en:True, innv:1,
#  Conn from 3 to 2, weight:1.0, en:True, innv:2,
#  Conn from 0 to 4, weight:1.0, en:True, innv:3,
#  Conn from 1 to 4, weight:1.0, en:True, innv:4,
#  Conn from 4 to 2, weight:1.0, en:True, innv:5]

# %%
g1.nodes
# Out:
# [input Node 0 , input Node 1 , output Node 2 , hidden Node 3 , hidden Node 4 ]

# %%
for i in range(20):
    p.run()
# Out:
# WEIGHT_MUTATION
# WEIGHT_MUTATION
# WEIGHT_MUTATION
# WEIGHT_MUTATION
# WEIGHT_MUTATION
# WEIGHT_MUTATION
# WEIGHT_MUTATION
# WEIGHT_MUTATION
# WEIGHT_MUTATION
# WEIGHT_MUTATION
# WEIGHT_MUTATION
# WEIGHT_MUTATION
# WEIGHT_MUTATION
# WEIGHT_MUTATION
# WEIGHT_MUTATION
# WEIGHT_MUTATION
# WEIGHT_MUTATION
# WEIGHT_MUTATION
# WEIGHT_MUTATION
# WEIGHT_MUTATION
# WEIGHT_MUTATION
# WEIGHT_MUTATION
# WEIGHT_MUTATION
# CROSSOVER
# WEIGHT_MUTATION
# WEIGHT_MUTATION
# WEIGHT_MUTATION
# WEIGHT_MUTATION
# WEIGHT_MUTATION
# WEIGHT_MUTATION
# WEIGHT_MUTATION
# WEIGHT_MUTATION
# WEIGHT_MUTATION
# WEIGHT_MUTATION
# WEIGHT_MUTATION
# WEIGHT_MUTATION
# WEIGHT_MUTATION
# WEIGHT_MUTATION
# WEIGHT_MUTATION
# WEIGHT_MUTATION
# WEIGHT_MUTATION
# WEIGHT_MUTATION
# WEIGHT_MUTATION
# WEIGHT_MUTATION
# WEIGHT_MUTATION
# WEIGHT_MUTATION
# WEIGHT_MUTATION
# CROSSOVER
# WEIGHT_MUTATION
# WEIGHT_MUTATION
# WEIGHT_MUTATION
# WEIGHT_MUTATION
# CROSSOVER
# WEIGHT_MUTATION
# WEIGHT_MUTATION
# WEIGHT_MUTATION
# WEIGHT_MUTATION
# WEIGHT_MUTATION
# WEIGHT_MUTATION
# WEIGHT_MUTATION
# WEIGHT_MUTATION
# WEIGHT_MUTATION
# WEIGHT_MUTATION
# WEIGHT_MUTATION
# WEIGHT_MUTATION
# WEIGHT_MUTATION
# WEIGHT_MUTATION
# WEIGHT_MUTATION
# WEIGHT_MUTATION
# CROSSOVER
# WEIGHT_MUTATION
# WEIGHT_MUTATION
# WEIGHT_MUTATION
# WEIGHT_MUTATION
# WEIGHT_MUTATION
# WEIGHT_MUTATION
# WEIGHT_MUTATION
# WEIGHT_MUTATION
# WEIGHT_MUTATION
# WEIGHT_MUTATION
# WEIGHT_MUTATION
# CROSSOVER
# WEIGHT_MUTATION
# WEIGHT_MUTATION
# WEIGHT_MUTATION
# WEIGHT_MUTATION
# NEW NODE
# CROSSOVER
# WEIGHT_MUTATION
# WEIGHT_MUTATION
# WEIGHT_MUTATION
# WEIGHT_MUTATION
# WEIGHT_MUTATION
# WEIGHT_MUTATION
# WEIGHT_MUTATION
# WEIGHT_MUTATION
# WEIGHT_MUTATION
# WEIGHT_MUTATION
# WEIGHT_MUTATION
# WEIGHT_MUTATION
# WEIGHT_MUTATION
# WEIGHT_MUTATION
# WEIGHT_MUTATION
# WEIGHT_MUTATION
# WEIGHT_MUTATION
# WEIGHT_MUTATION
# WEIGHT_MUTATION
# WEIGHT_MUTATION
# WEIGHT_MUTATION
# WEIGHT_MUTATION
# WEIGHT_MUTATION
# CROSSOVER
# WEIGHT_MUTATION
# WEIGHT_MUTATION
# WEIGHT_MUTATION
# WEIGHT_MUTATION
# WEIGHT_MUTATION
# WEIGHT_MUTATION
# WEIGHT_MUTATION
# WEIGHT_MUTATION
# WEIGHT_MUTATION
# WEIGHT_MUTATION
# WEIGHT_MUTATION
# CROSSOVER
# WEIGHT_MUTATION
# WEIGHT_MUTATION
# WEIGHT_MUTATION
# WEIGHT_MUTATION
# WEIGHT_MUTATION
# WEIGHT_MUTATION
# WEIGHT_MUTATION
# WEIGHT_MUTATION
# WEIGHT_MUTATION
# WEIGHT_MUTATION
# WEIGHT_MUTATION
# WEIGHT_MUTATION
# WEIGHT_MUTATION
# WEIGHT_MUTATION
# WEIGHT_MUTATION
# WEIGHT_MUTATION
# WEIGHT_MUTATION
# WEIGHT_MUTATION
# WEIGHT_MUTATION
# WEIGHT_MUTATION
# WEIGHT_MUTATION
# WEIGHT_MUTATION
# WEIGHT_MUTATION
# WEIGHT_MUTATION
# WEIGHT_MUTATION
# WEIGHT_MUTATION
# WEIGHT_MUTATION
# WEIGHT_MUTATION
# WEIGHT_MUTATION
# WEIGHT_MUTATION
# WEIGHT_MUTATION
# WEIGHT_MUTATION
# WEIGHT_MUTATION
# WEIGHT_MUTATION
# WEIGHT_MUTATION
# WEIGHT_MUTATION
# WEIGHT_MUTATION
# WEIGHT_MUTATION
# input: [0, 0], output: [0.3935914990263237], truth: 0
# input: [0, 1], output: [0.7557413825566744], truth: 1
# input: [1, 0], output: [0.12679009947047765], truth: 1
# input: [1, 1], output: [0.4139429245012317], truth: 0
# input: [0, 0], output: [0.41285785699278943], truth: 0
# input: [0, 1], output: [0.5419476189596008], truth: 1
# input: [1, 0], output: [0.15011527979578054], truth: 1
# input: [1, 1], output: [0.2285755377131629], truth: 0
# input: [0, 0], output: [0.2939767086335812], truth: 0
# input: [0, 1], output: [0.4549406568524735], truth: 1
# input: [1, 0], output: [0.1837469118167415], truth: 1
# input: [1, 1], output: [0.3087472556751478], truth: 0
# input: [0, 0], output: [0.4114216160375992], truth: 0
# input: [0, 1], output: [0.4745060572318567], truth: 1
# input: [1, 0], output: [0.13248508702737744], truth: 1
# input: [1, 1], output: [0.16439022173079762], truth: 0
# input: [0, 0], output: [0.3124740239683487], truth: 0
# input: [0, 1], output: [0.23256471171474066], truth: 1
# input: [1, 0], output: [0.2157192767286684], truth: 1
# input: [1, 1], output: [0.15401960308469012], truth: 0
# input: [0, 0], output: [0.46105480872272453], truth: 0
# input: [0, 1], output: [0.6627978255015496], truth: 1
# input: [1, 0], output: [0.4508019777966602], truth: 1
# input: [1, 1], output: [0.620517462736831], truth: 0
# input: [0, 0], output: [0.4198559114749865], truth: 0
# input: [0, 1], output: [0.6114573140044777], truth: 1
# input: [1, 0], output: [0.4054930029586992], truth: 1
# input: [1, 1], output: [0.596296423922074], truth: 0
# input: [0, 0], output: [0.6203383006919938], truth: 0
# input: [0, 1], output: [0.6423746525742089], truth: 1
# input: [1, 0], output: [0.5219457096063576], truth: 1
# input: [1, 1], output: [0.5440018951405657], truth: 0
# input: [0, 0], output: [0.49200442786487814], truth: 0
# input: [0, 1], output: [0.49780845393538276], truth: 1
# input: [1, 0], output: [0.7431582044906864], truth: 1
# input: [1, 1], output: [0.7499162102728801], truth: 0
# input: [0, 0], output: [0.17201684495623298], truth: 0
# input: [0, 1], output: [0.6297975367110548], truth: 1
# input: [1, 0], output: [0.11305006973710306], truth: 1
# input: [1, 1], output: [0.5086449452866199], truth: 0
# input: [0, 0], output: [0.36860252663830145], truth: 0
# input: [0, 1], output: [0.5111591811718632], truth: 1
# input: [1, 0], output: [0.24245037922586057], truth: 1
# input: [1, 1], output: [0.3519252763065347], truth: 0
# input: [0, 0], output: [0.26704811901280895], truth: 0
# input: [0, 1], output: [0.35861162768813903], truth: 1
# input: [1, 0], output: [0.17365794114575658], truth: 1
# input: [1, 1], output: [0.24538529926325553], truth: 0
# input: [0, 0], output: [0.6907629113819085], truth: 0
# input: [0, 1], output: [0.7548689824765207], truth: 1
# input: [1, 0], output: [0.7189083066280035], truth: 1
# input: [1, 1], output: [0.7790460238503795], truth: 0
# input: [0, 0], output: [0.6966886100671036], truth: 0
# input: [0, 1], output: [0.8553487809518203], truth: 1
# input: [1, 0], output: [0.39650897869684665], truth: 1
# input: [1, 1], output: [0.5975076040520467], truth: 0
# input: [0, 0], output: [0.5993218244938778], truth: 0
# input: [0, 1], output: [0.5222222844848444], truth: 1
# input: [1, 0], output: [0.3181411959462349], truth: 1
# input: [1, 1], output: [0.2543010363793347], truth: 0
# input: [0, 0], output: [0.3679260486467388], truth: 0
# input: [0, 1], output: [0.5276646385378815], truth: 1
# input: [1, 0], output: [0.10864596377401754], truth: 1
# input: [1, 1], output: [0.18978397278357428], truth: 0
# input: [0, 0], output: [0.39796502298913955], truth: 0
# input: [0, 1], output: [0.5094444076570294], truth: 1
# input: [1, 0], output: [0.2660072079110777], truth: 1
# input: [1, 1], output: [0.3631312693510734], truth: 0
# input: [0, 0], output: [0.6194389625559552], truth: 0
# input: [0, 1], output: [0.3736147716123707], truth: 1
# input: [1, 0], output: [0.34318691614608277], truth: 1
# input: [1, 1], output: [0.16066726324618313], truth: 0
# input: [0, 0], output: [0.4092783740527773], truth: 0
# input: [0, 1], output: [0.5330887837344822], truth: 1
# input: [1, 0], output: [0.21917068723884653], truth: 1
# input: [1, 1], output: [0.3162652693242954], truth: 0
# input: [0, 0], output: [0.6488606342564505], truth: 0
# input: [0, 1], output: [0.5745563793912267], truth: 1
# input: [1, 0], output: [0.1988825127329044], truth: 1
# input: [1, 1], output: [0.15098262122967862], truth: 0
# input: [0, 0], output: [0.5492891081790269], truth: 0
# input: [0, 1], output: [0.6879660225641768], truth: 1
# input: [1, 0], output: [0.211532512428109], truth: 1
# input: [1, 1], output: [0.33187418333740604], truth: 0
# input: [0, 0], output: [0.2182686776421854], truth: 0
# input: [0, 1], output: [0.22582314872717185], truth: 1
# input: [1, 0], output: [0.34677887325583645], truth: 1
# input: [1, 1], output: [0.3436470516478066], truth: 0
# input: [0, 0], output: [0.6307371900630642], truth: 0
# input: [0, 1], output: [0.7392689832535013], truth: 1
# input: [1, 0], output: [0.275077999055609], truth: 1
# input: [1, 1], output: [0.3864599054416824], truth: 0
# input: [0, 0], output: [0.5646514569058392], truth: 0
# input: [0, 1], output: [0.7014972753235528], truth: 1
# input: [1, 0], output: [0.25036903475063493], truth: 1
# input: [1, 1], output: [0.3694544060701941], truth: 0
# input: [0, 0], output: [0.3605106388022134], truth: 0
# input: [0, 1], output: [0.4493288901815972], truth: 1
# input: [1, 0], output: [0.43085323337284104], truth: 1
# input: [1, 1], output: [0.4649510636200506], truth: 0
# input: [0, 0], output: [0.6608070892784736], truth: 0
# input: [0, 1], output: [0.8003587473784165], truth: 1
# input: [1, 0], output: [0.6737411318146765], truth: 1
# input: [1, 1], output: [0.8096409014354335], truth: 0
# input: [0, 0], output: [0.2963592985095209], truth: 0
# input: [0, 1], output: [0.30258005810983146], truth: 1
# input: [1, 0], output: [0.3777242268089771], truth: 1
# input: [1, 1], output: [0.3544743520967355], truth: 0
# input: [0, 0], output: [0.3872359347947931], truth: 0
# input: [0, 1], output: [0.5293256832739077], truth: 1
# input: [1, 0], output: [0.21104013494955332], truth: 1
# input: [1, 1], output: [0.3228759537397901], truth: 0
# input: [0, 0], output: [0.217123061364742], truth: 0
# input: [0, 1], output: [0.18650769043445073], truth: 1
# input: [1, 0], output: [0.2456576644104582], truth: 1
# input: [1, 1], output: [0.21180055897310807], truth: 0
# input: [0, 0], output: [0.6118378518432267], truth: 0
# input: [0, 1], output: [0.5674598615312955], truth: 1
# input: [1, 0], output: [0.4347902068042378], truth: 1
# input: [1, 1], output: [0.39033371444418297], truth: 0
# input: [0, 0], output: [0.3625233868746215], truth: 0
# input: [0, 1], output: [0.7180881543709982], truth: 1
# input: [1, 0], output: [0.19052581787656706], truth: 1
# input: [1, 1], output: [0.5105072165001113], truth: 0
# input: [0, 0], output: [0.5156443521061896], truth: 0
# input: [0, 1], output: [0.425536026252574], truth: 1
# input: [1, 0], output: [0.4681539956299556], truth: 1
# input: [1, 1], output: [0.3811325926930681], truth: 0
# input: [0, 0], output: [0.3951426518602825], truth: 0
# input: [0, 1], output: [0.5485781255805793], truth: 1
# input: [1, 0], output: [0.27983883310434915], truth: 1
# input: [1, 1], output: [0.40483004893863], truth: 0
# input: [0, 0], output: [0.4525198943077958], truth: 0
# input: [0, 1], output: [0.5772625984677989], truth: 1
# input: [1, 0], output: [0.34079842153287654], truth: 1
# input: [1, 1], output: [0.4605525650473575], truth: 0
# input: [0, 0], output: [0.5003716992069388], truth: 0
# input: [0, 1], output: [0.33617995230951386], truth: 1
# input: [1, 0], output: [0.399863651700254], truth: 1
# input: [1, 1], output: [0.2549657192352744], truth: 0
# input: [0, 0], output: [0.28328492825541346], truth: 0
# input: [0, 1], output: [0.4222479690801291], truth: 1
# input: [1, 0], output: [0.200436029032998], truth: 1
# input: [1, 1], output: [0.3153179582965295], truth: 0
# input: [0, 0], output: [0.6874446007485507], truth: 0
# input: [0, 1], output: [0.8816468162686348], truth: 1
# input: [1, 0], output: [0.8623155385376619], truth: 1
# input: [1, 1], output: [0.9550605311931002], truth: 0
# input: [0, 0], output: [0.4576080351437889], truth: 0
# input: [0, 1], output: [0.568319288304437], truth: 1
# input: [1, 0], output: [0.352351976099107], truth: 1
# input: [1, 1], output: [0.46181808294933163], truth: 0
# input: [0, 0], output: [0.34109082455467704], truth: 0
# input: [0, 1], output: [0.26199195870517283], truth: 1
# input: [1, 0], output: [0.1984671640659938], truth: 1
# input: [1, 1], output: [0.14423964063152533], truth: 0
# input: [0, 0], output: [0.40620873087933723], truth: 0
# input: [0, 1], output: [0.6719548203795798], truth: 1
# input: [1, 0], output: [0.3216676492038707], truth: 1
# input: [1, 1], output: [0.5839877027408626], truth: 0
# #############################################
# ***Generation 2***
# Species: 1
# Species 0 has 40 members, top 5 are [Genome with 5 nodes and 6 connections. Fitness: 4.41612245952999, Genome with 5 nodes and 6 connections. Fitness: 4.320580374841267, Genome with 5 nodes and 6 connections. Fitness: 4.305612792781978, Genome with 5 nodes and 6 connections. Fitness: 4.25261034055834, Genome with 5 nodes and 6 connections. Fitness: 4.221876009017579]
# Top 5 genomes are [Genome with 5 nodes and 6 connections. Fitness: 4.41612245952999, Genome with 5 nodes and 6 connections. Fitness: 4.320580374841267, Genome with 5 nodes and 6 connections. Fitness: 4.305612792781978, Genome with 5 nodes and 6 connections. Fitness: 4.25261034055834, Genome with 5 nodes and 6 connections. Fitness: 4.221876009017579]
# WEIGHT_MUTATION
# WEIGHT_MUTATION
# WEIGHT_MUTATION
# WEIGHT_MUTATION
# WEIGHT_MUTATION
# WEIGHT_MUTATION
# WEIGHT_MUTATION
# WEIGHT_MUTATION
# WEIGHT_MUTATION
# WEIGHT_MUTATION
# WEIGHT_MUTATION
# WEIGHT_MUTATION
# WEIGHT_MUTATION
# WEIGHT_MUTATION
# WEIGHT_MUTATION
# WEIGHT_MUTATION
# WEIGHT_MUTATION
# WEIGHT_MUTATION
# WEIGHT_MUTATION
# WEIGHT_MUTATION
# WEIGHT_MUTATION
# WEIGHT_MUTATION
# WEIGHT_MUTATION
# WEIGHT_MUTATION
# WEIGHT_MUTATION
# WEIGHT_MUTATION
# WEIGHT_MUTATION
# WEIGHT_MUTATION
# WEIGHT_MUTATION
# WEIGHT_MUTATION
# WEIGHT_MUTATION
# WEIGHT_MUTATION
# WEIGHT_MUTATION
# WEIGHT_MUTATION
# WEIGHT_MUTATION
# WEIGHT_MUTATION
# WEIGHT_MUTATION
# WEIGHT_MUTATION
# WEIGHT_MUTATION
# WEIGHT_MUTATION
# WEIGHT_MUTATION
# WEIGHT_MUTATION
# WEIGHT_MUTATION
# WEIGHT_MUTATION
# WEIGHT_MUTATION
# WEIGHT_MUTATION
# WEIGHT_MUTATION
# WEIGHT_MUTATION
# WEIGHT_MUTATION
# WEIGHT_MUTATION
# WEIGHT_MUTATION
# CROSSOVER
# WEIGHT_MUTATION
# WEIGHT_MUTATION
# WEIGHT_MUTATION
# WEIGHT_MUTATION
# WEIGHT_MUTATION
# WEIGHT_MUTATION
# WEIGHT_MUTATION
# WEIGHT_MUTATION
# WEIGHT_MUTATION
# WEIGHT_MUTATION
# WEIGHT_MUTATION
# WEIGHT_MUTATION
# WEIGHT_MUTATION
# WEIGHT_MUTATION
# WEIGHT_MUTATION
# WEIGHT_MUTATION
# WEIGHT_MUTATION
# WEIGHT_MUTATION
# WEIGHT_MUTATION
# WEIGHT_MUTATION
# WEIGHT_MUTATION
# WEIGHT_MUTATION
# WEIGHT_MUTATION
# WEIGHT_MUTATION
# WEIGHT_MUTATION
# WEIGHT_MUTATION
# WEIGHT_MUTATION
# WEIGHT_MUTATION
# WEIGHT_MUTATION
# WEIGHT_MUTATION
# WEIGHT_MUTATION
# CROSSOVER
# CROSSOVER
# WEIGHT_MUTATION
# WEIGHT_MUTATION
# WEIGHT_MUTATION
# WEIGHT_MUTATION
# WEIGHT_MUTATION
# WEIGHT_MUTATION
# WEIGHT_MUTATION
# WEIGHT_MUTATION
# WEIGHT_MUTATION
# WEIGHT_MUTATION
# WEIGHT_MUTATION
# WEIGHT_MUTATION
# WEIGHT_MUTATION
# WEIGHT_MUTATION
# WEIGHT_MUTATION
# CROSSOVER
# WEIGHT_MUTATION
# WEIGHT_MUTATION
# WEIGHT_MUTATION
# WEIGHT_MUTATION
# WEIGHT_MUTATION
# WEIGHT_MUTATION
# WEIGHT_MUTATION
# WEIGHT_MUTATION
# WEIGHT_MUTATION
# WEIGHT_MUTATION
# WEIGHT_MUTATION
# WEIGHT_MUTATION
# WEIGHT_MUTATION
# WEIGHT_MUTATION
# WEIGHT_MUTATION
# WEIGHT_MUTATION
# NEW NODE
# WEIGHT_MUTATION
# WEIGHT_MUTATION
# WEIGHT_MUTATION
# WEIGHT_MUTATION
# WEIGHT_MUTATION
# WEIGHT_MUTATION
# WEIGHT_MUTATION
# WEIGHT_MUTATION
# WEIGHT_MUTATION
# WEIGHT_MUTATION
# WEIGHT_MUTATION
# WEIGHT_MUTATION
# CROSSOVER
# WEIGHT_MUTATION
# WEIGHT_MUTATION
# WEIGHT_MUTATION
# WEIGHT_MUTATION
# WEIGHT_MUTATION
# WEIGHT_MUTATION
# WEIGHT_MUTATION
# WEIGHT_MUTATION
# WEIGHT_MUTATION
# CROSSOVER
# CROSSOVER
# CROSSOVER
# WEIGHT_MUTATION
# WEIGHT_MUTATION
# WEIGHT_MUTATION
# WEIGHT_MUTATION
# WEIGHT_MUTATION
# WEIGHT_MUTATION
# WEIGHT_MUTATION
# WEIGHT_MUTATION
# WEIGHT_MUTATION
# CROSSOVER
# input: [0, 0], output: [0.6874446007485507], truth: 0
# input: [0, 1], output: [0.8816468162686348], truth: 1
# input: [1, 0], output: [0.8623155385376619], truth: 1
# input: [1, 1], output: [0.9550605311931004], truth: 0
# input: [0, 0], output: [0.3679260486467388], truth: 0
# input: [0, 1], output: [0.5276646385378815], truth: 1
# input: [1, 0], output: [0.10864596377401754], truth: 1
# input: [1, 1], output: [0.18978397278357423], truth: 0
# input: [0, 0], output: [0.3935914990263237], truth: 0
# input: [0, 1], output: [0.7557413825566744], truth: 1
# input: [1, 0], output: [0.12679009947047765], truth: 1
# input: [1, 1], output: [0.4139429245012317], truth: 0
# input: [0, 0], output: [0.17201684495623298], truth: 0
# input: [0, 1], output: [0.6297975367110548], truth: 1
# input: [1, 0], output: [0.11305006973710306], truth: 1
# input: [1, 1], output: [0.5086449452866199], truth: 0
# input: [0, 0], output: [0.12638404937048703], truth: 0
# input: [0, 1], output: [0.24373035972065873], truth: 1
# input: [1, 0], output: [0.13876140588038943], truth: 1
# input: [1, 1], output: [0.226083054541664], truth: 0
# input: [0, 0], output: [0.3565633872315371], truth: 0
# input: [0, 1], output: [0.8720473551246363], truth: 1
# input: [1, 0], output: [0.13949367295464285], truth: 1
# input: [1, 1], output: [0.6679341259687318], truth: 0
# input: [0, 0], output: [0.4266672391019729], truth: 0
# input: [0, 1], output: [0.5339090202465795], truth: 1
# input: [1, 0], output: [0.361355809207281], truth: 1
# input: [1, 1], output: [0.4655103830312313], truth: 0
# input: [0, 0], output: [0.28023884241334923], truth: 0
# input: [0, 1], output: [0.264713938185958], truth: 1
# input: [1, 0], output: [0.12016799114865402], truth: 1
# input: [1, 1], output: [0.11221300162491463], truth: 0
# input: [0, 0], output: [0.12306632596580686], truth: 0
# input: [0, 1], output: [0.20841046454389003], truth: 1
# input: [1, 0], output: [0.19017580542649726], truth: 1
# input: [1, 1], output: [0.26269597214803214], truth: 0
# input: [0, 0], output: [0.7216994490282654], truth: 0
# input: [0, 1], output: [0.8647129114068871], truth: 1
# input: [1, 0], output: [0.8761192085434497], truth: 1
# input: [1, 1], output: [0.9469702188329372], truth: 0
# input: [0, 0], output: [0.259276555564533], truth: 0
# input: [0, 1], output: [0.33165245984258995], truth: 1
# input: [1, 0], output: [0.10852568000110316], truth: 1
# input: [1, 1], output: [0.14587688534217547], truth: 0
# input: [0, 0], output: [0.29765444100865546], truth: 0
# input: [0, 1], output: [0.40099370266907663], truth: 1
# input: [1, 0], output: [0.14172477972166192], truth: 1
# input: [1, 1], output: [0.2081337613208969], truth: 0
# input: [0, 0], output: [0.38100372141975447], truth: 0
# input: [0, 1], output: [0.24129250442286715], truth: 1
# input: [1, 0], output: [0.1324578140929752], truth: 1
# input: [1, 1], output: [0.07394342894839798], truth: 0
# input: [0, 0], output: [0.5822484194979247], truth: 0
# input: [0, 1], output: [0.613636169183872], truth: 1
# input: [1, 0], output: [0.26536128905192125], truth: 1
# input: [1, 1], output: [0.284794999967022], truth: 0
# input: [0, 0], output: [0.3655576011192226], truth: 0
# input: [0, 1], output: [0.6203455604228906], truth: 1
# input: [1, 0], output: [0.21692257797969436], truth: 1
# input: [1, 1], output: [0.43190279850335744], truth: 0
# input: [0, 0], output: [0.34685760153583733], truth: 0
# input: [0, 1], output: [0.23075188123746232], truth: 1
# input: [1, 0], output: [0.20529507461062652], truth: 1
# input: [1, 1], output: [0.12585849479116817], truth: 0
# input: [0, 0], output: [0.48422689650586903], truth: 0
# input: [0, 1], output: [0.7204255133534743], truth: 1
# input: [1, 0], output: [0.2122989541659503], truth: 1
# input: [1, 1], output: [0.4237245672608469], truth: 0
# input: [0, 0], output: [0.19544101335291234], truth: 0
# input: [0, 1], output: [0.388383055058061], truth: 1
# input: [1, 0], output: [0.13492240060136698], truth: 1
# input: [1, 1], output: [0.2859690572120468], truth: 0
# input: [0, 0], output: [0.17782345393090868], truth: 0
# input: [0, 1], output: [0.4526838762234678], truth: 1
# input: [1, 0], output: [0.21785337091360077], truth: 1
# input: [1, 1], output: [0.5073585248565238], truth: 0
# input: [0, 0], output: [0.3687705645313309], truth: 0
# input: [0, 1], output: [0.3558983017038894], truth: 1
# input: [1, 0], output: [0.19010251597681624], truth: 1
# input: [1, 1], output: [0.18110283344609923], truth: 0
# input: [0, 0], output: [0.41352712621760146], truth: 0
# input: [0, 1], output: [0.6970070180255471], truth: 1
# input: [1, 0], output: [0.11726294903268875], truth: 1
# input: [1, 1], output: [0.3087323601321758], truth: 0
# input: [0, 0], output: [0.3390463815042455], truth: 0
# input: [0, 1], output: [0.49776554459341793], truth: 1
# input: [1, 0], output: [0.20430452171556243], truth: 1
# input: [1, 1], output: [0.3315134963860164], truth: 0
# input: [0, 0], output: [0.4242186693464515], truth: 0
# input: [0, 1], output: [0.7511261079125855], truth: 1
# input: [1, 0], output: [0.3751750072828646], truth: 1
# input: [1, 1], output: [0.6621912343170915], truth: 0
# input: [0, 0], output: [0.21432683539225317], truth: 0
# input: [0, 1], output: [0.5539977125676288], truth: 1
# input: [1, 0], output: [0.13687320744983386], truth: 1
# input: [1, 1], output: [0.4070673636662203], truth: 0
# input: [0, 0], output: [0.37975892353620117], truth: 0
# input: [0, 1], output: [0.2845488293610088], truth: 1
# input: [1, 0], output: [0.2144212986825687], truth: 1
# input: [1, 1], output: [0.1446726973892311], truth: 0
# input: [0, 0], output: [0.4114216160375992], truth: 0
# input: [0, 1], output: [0.4745060572318567], truth: 1
# input: [1, 0], output: [0.13248508702737744], truth: 1
# input: [1, 1], output: [0.16439022173079762], truth: 0
# input: [0, 0], output: [0.43809463119013453], truth: 0
# input: [0, 1], output: [0.6946836747752841], truth: 1
# input: [1, 0], output: [0.08877503252122403], truth: 1
# input: [1, 1], output: [0.22862627468018654], truth: 0
# input: [0, 0], output: [0.3935914990263237], truth: 0
# input: [0, 1], output: [0.7246143539424991], truth: 1
# input: [1, 0], output: [0.14514576634623952], truth: 1
# input: [1, 1], output: [0.40579340412899595], truth: 0
# input: [0, 0], output: [0.42602379658801154], truth: 0
# input: [0, 1], output: [0.3743223724211488], truth: 1
# input: [1, 0], output: [0.2009466713165058], truth: 1
# input: [1, 1], output: [0.16857199687602697], truth: 0
# input: [0, 0], output: [0.3900966517073521], truth: 0
# input: [0, 1], output: [0.6346617591219954], truth: 1
# input: [1, 0], output: [0.29584915775169246], truth: 1
# input: [1, 1], output: [0.532668676086915], truth: 0
# input: [0, 0], output: [0.45482203333734955], truth: 0
# input: [0, 1], output: [0.5866479859255864], truth: 1
# input: [1, 0], output: [0.1761288814020859], truth: 1
# input: [1, 1], output: [0.26652574827936654], truth: 0
# input: [0, 0], output: [0.24914481040659936], truth: 0
# input: [0, 1], output: [0.3313142979633858], truth: 1
# input: [1, 0], output: [0.053102895218422805], truth: 1
# input: [1, 1], output: [0.07727315428358364], truth: 0
# input: [0, 0], output: [0.33535959266809934], truth: 0
# input: [0, 1], output: [0.44698345763055414], truth: 1
# input: [1, 0], output: [0.2741234360635573], truth: 1
# input: [1, 1], output: [0.3749909543824798], truth: 0
# input: [0, 0], output: [0.34809211296081355], truth: 0
# input: [0, 1], output: [0.34788160620544173], truth: 1
# input: [1, 0], output: [0.4324960469520663], truth: 1
# input: [1, 1], output: [0.41355366648545533], truth: 0
# input: [0, 0], output: [0.3271781360516362], truth: 0
# input: [0, 1], output: [0.3794471715258749], truth: 1
# input: [1, 0], output: [0.2242442175773815], truth: 1
# input: [1, 1], output: [0.26658451898007696], truth: 0
# input: [0, 0], output: [0.36826422286026345], truth: 0
# input: [0, 1], output: [0.516514895434338], truth: 1
# input: [1, 0], output: [0.1647620627445709], truth: 1
# input: [1, 1], output: [0.26310698100050167], truth: 0
# input: [0, 0], output: [0.38008439811725225], truth: 0
# input: [0, 1], output: [0.6096281017204768], truth: 1
# input: [1, 0], output: [0.2217481997259341], truth: 1
# input: [1, 1], output: [0.42089416086091863], truth: 0
# input: [0, 0], output: [0.37433414227562245], truth: 0
# input: [0, 1], output: [0.6314237224859056], truth: 1
# input: [1, 0], output: [0.33153766219364134], truth: 1
# input: [1, 1], output: [0.5637034344955963], truth: 0
# input: [0, 0], output: [0.2592193860111671], truth: 0
# input: [0, 1], output: [0.564654737352327], truth: 1
# input: [1, 0], output: [0.07530054463476168], truth: 1
# input: [1, 1], output: [0.2272547325725821], truth: 0
# input: [0, 0], output: [0.39988934615472344], truth: 0
# input: [0, 1], output: [0.5508315557473655], truth: 1
# input: [1, 0], output: [0.1882305989113318], truth: 1
# input: [1, 1], output: [0.29824589596051126], truth: 0
# #############################################
# ***Generation 3***
# Species: 1
# Species 0 has 40 members, top 5 are [Genome with 5 nodes and 6 connections. Fitness: 4.637481121133001, Genome with 5 nodes and 6 connections. Fitness: 4.480578919986569, Genome with 5 nodes and 6 connections. Fitness: 4.41612245952999, Genome with 5 nodes and 6 connections. Fitness: 4.376507851394035, Genome with 5 nodes and 6 connections. Fitness: 4.320580374841267]
# Top 5 genomes are [Genome with 5 nodes and 6 connections. Fitness: 4.637481121133001, Genome with 5 nodes and 6 connections. Fitness: 4.480578919986569, Genome with 5 nodes and 6 connections. Fitness: 4.41612245952999, Genome with 5 nodes and 6 connections. Fitness: 4.376507851394035, Genome with 5 nodes and 6 connections. Fitness: 4.320580374841267]
# CROSSOVER
# WEIGHT_MUTATION
# WEIGHT_MUTATION
# WEIGHT_MUTATION
# WEIGHT_MUTATION
# WEIGHT_MUTATION
# WEIGHT_MUTATION
# WEIGHT_MUTATION
# WEIGHT_MUTATION
# WEIGHT_MUTATION
# CROSSOVER
# WEIGHT_MUTATION
# WEIGHT_MUTATION
# WEIGHT_MUTATION
# WEIGHT_MUTATION
# WEIGHT_MUTATION
# WEIGHT_MUTATION
# WEIGHT_MUTATION
# WEIGHT_MUTATION
# WEIGHT_MUTATION
# WEIGHT_MUTATION
# WEIGHT_MUTATION
# WEIGHT_MUTATION
# WEIGHT_MUTATION
# CROSSOVER
# WEIGHT_MUTATION
# WEIGHT_MUTATION
# WEIGHT_MUTATION
# WEIGHT_MUTATION
# CROSSOVER
# WEIGHT_MUTATION
# WEIGHT_MUTATION
# WEIGHT_MUTATION
# WEIGHT_MUTATION
# WEIGHT_MUTATION
# CROSSOVER
# WEIGHT_MUTATION
# WEIGHT_MUTATION
# WEIGHT_MUTATION
# WEIGHT_MUTATION
# WEIGHT_MUTATION
# WEIGHT_MUTATION
# WEIGHT_MUTATION
# WEIGHT_MUTATION
# WEIGHT_MUTATION
# WEIGHT_MUTATION
# WEIGHT_MUTATION
# WEIGHT_MUTATION
# WEIGHT_MUTATION
# WEIGHT_MUTATION
# WEIGHT_MUTATION
# WEIGHT_MUTATION
# WEIGHT_MUTATION
# WEIGHT_MUTATION
# WEIGHT_MUTATION
# CROSSOVER
# CROSSOVER
# WEIGHT_MUTATION
# WEIGHT_MUTATION
# WEIGHT_MUTATION
# WEIGHT_MUTATION
# WEIGHT_MUTATION
# WEIGHT_MUTATION
# WEIGHT_MUTATION
# WEIGHT_MUTATION
# WEIGHT_MUTATION
# WEIGHT_MUTATION
# WEIGHT_MUTATION
# WEIGHT_MUTATION
# WEIGHT_MUTATION
# WEIGHT_MUTATION
# WEIGHT_MUTATION
# WEIGHT_MUTATION
# CROSSOVER
# WEIGHT_MUTATION
# WEIGHT_MUTATION
# WEIGHT_MUTATION
# WEIGHT_MUTATION
# WEIGHT_MUTATION
# WEIGHT_MUTATION
# CROSSOVER
# CROSSOVER
# WEIGHT_MUTATION
# WEIGHT_MUTATION
# WEIGHT_MUTATION
# WEIGHT_MUTATION
# WEIGHT_MUTATION
# WEIGHT_MUTATION
# WEIGHT_MUTATION
# WEIGHT_MUTATION
# WEIGHT_MUTATION
# WEIGHT_MUTATION
# WEIGHT_MUTATION
# WEIGHT_MUTATION
# WEIGHT_MUTATION
# WEIGHT_MUTATION
# WEIGHT_MUTATION
# WEIGHT_MUTATION
# WEIGHT_MUTATION
# WEIGHT_MUTATION
# CROSSOVER
# WEIGHT_MUTATION
# WEIGHT_MUTATION
# WEIGHT_MUTATION
# WEIGHT_MUTATION
# WEIGHT_MUTATION
# WEIGHT_MUTATION
# WEIGHT_MUTATION
# WEIGHT_MUTATION
# WEIGHT_MUTATION
# WEIGHT_MUTATION
# WEIGHT_MUTATION
# WEIGHT_MUTATION
# WEIGHT_MUTATION
# WEIGHT_MUTATION
# WEIGHT_MUTATION
# WEIGHT_MUTATION
# WEIGHT_MUTATION
# WEIGHT_MUTATION
# WEIGHT_MUTATION
# WEIGHT_MUTATION
# WEIGHT_MUTATION
# WEIGHT_MUTATION
# WEIGHT_MUTATION
# WEIGHT_MUTATION
# WEIGHT_MUTATION
# WEIGHT_MUTATION
# WEIGHT_MUTATION
# WEIGHT_MUTATION
# NEW NODE
# WEIGHT_MUTATION
# WEIGHT_MUTATION
# WEIGHT_MUTATION
# WEIGHT_MUTATION
# WEIGHT_MUTATION
# WEIGHT_MUTATION
# WEIGHT_MUTATION
# WEIGHT_MUTATION
# WEIGHT_MUTATION
# WEIGHT_MUTATION
# WEIGHT_MUTATION
# WEIGHT_MUTATION
# WEIGHT_MUTATION
# WEIGHT_MUTATION
# input: [0, 0], output: [0.2592193860111671], truth: 0
# input: [0, 1], output: [0.564654737352327], truth: 1
# input: [1, 0], output: [0.07530054463476168], truth: 1
# input: [1, 1], output: [0.2272547325725821], truth: 0
# input: [0, 0], output: [0.43809463119013453], truth: 0
# input: [0, 1], output: [0.6946836747752841], truth: 1
# input: [1, 0], output: [0.08877503252122403], truth: 1
# input: [1, 1], output: [0.22862627468018654], truth: 0
# input: [0, 0], output: [0.6874446007485507], truth: 0
# input: [0, 1], output: [0.8816468162686348], truth: 1
# input: [1, 0], output: [0.8623155385376619], truth: 1
# input: [1, 1], output: [0.9550605311931002], truth: 0
# input: [0, 0], output: [0.41352712621760146], truth: 0
# input: [0, 1], output: [0.6970070180255471], truth: 1
# input: [1, 0], output: [0.11726294903268875], truth: 1
# input: [1, 1], output: [0.3087323601321758], truth: 0
# input: [0, 0], output: [0.311128196396118], truth: 0
# input: [0, 1], output: [0.5404404843893836], truth: 1
# input: [1, 0], output: [0.11305802196285343], truth: 1
# input: [1, 1], output: [0.2444945380584515], truth: 0
# input: [0, 0], output: [0.19881903423613556], truth: 0
# input: [0, 1], output: [0.6166295698011232], truth: 1
# input: [1, 0], output: [0.055678831677210675], truth: 1
# input: [1, 1], output: [0.2843520833267432], truth: 0
# input: [0, 0], output: [0.11516861747758438], truth: 0
# input: [0, 1], output: [0.3734455076963745], truth: 1
# input: [1, 0], output: [0.06867123670555324], truth: 1
# input: [1, 1], output: [0.25546518963829395], truth: 0
# input: [0, 0], output: [0.303229299479236], truth: 0
# input: [0, 1], output: [0.5335421718150695], truth: 1
# input: [1, 0], output: [0.10771234799502406], truth: 1
# input: [1, 1], output: [0.24093237328193712], truth: 0
# input: [0, 0], output: [0.7216994490282654], truth: 0
# input: [0, 1], output: [0.8260318588283169], truth: 1
# input: [1, 0], output: [0.7225269785082232], truth: 1
# input: [1, 1], output: [0.8311901253545844], truth: 0
# input: [0, 0], output: [0.26001159761908005], truth: 0
# input: [0, 1], output: [0.3693270781727534], truth: 1
# input: [1, 0], output: [0.09351627185026677], truth: 1
# input: [1, 1], output: [0.13631149157111724], truth: 0
# input: [0, 0], output: [0.32435126388046115], truth: 0
# input: [0, 1], output: [0.744705328995753], truth: 1
# input: [1, 0], output: [0.23109705741566233], truth: 1
# input: [1, 1], output: [0.6281044999747365], truth: 0
# input: [0, 0], output: [0.311128196396118], truth: 0
# input: [0, 1], output: [0.7164985367796315], truth: 1
# input: [1, 0], output: [0.04195406184778832], truth: 1
# input: [1, 1], output: [0.19686501351313737], truth: 0
# input: [0, 0], output: [0.3807153998142496], truth: 0
# input: [0, 1], output: [0.6299086597850504], truth: 1
# input: [1, 0], output: [0.2786851394973651], truth: 1
# input: [1, 1], output: [0.5043677569632132], truth: 0
# input: [0, 0], output: [0.526876426967046], truth: 0
# input: [0, 1], output: [0.653192676960128], truth: 1
# input: [1, 0], output: [0.23681867071526358], truth: 1
# input: [1, 1], output: [0.34361345176987335], truth: 0
# input: [0, 0], output: [0.4846066487013056], truth: 0
# input: [0, 1], output: [0.8871566471252955], truth: 1
# input: [1, 0], output: [0.23307130502241552], truth: 1
# input: [1, 1], output: [0.7175150407096429], truth: 0
# input: [0, 0], output: [0.27246626236300275], truth: 0
# input: [0, 1], output: [0.3649895347046258], truth: 1
# input: [1, 0], output: [0.12108066503245442], truth: 1
# input: [1, 1], output: [0.1755560031087264], truth: 0
# input: [0, 0], output: [0.23989648414492057], truth: 0
# input: [0, 1], output: [0.5440408430960154], truth: 1
# input: [1, 0], output: [0.05478677911019787], truth: 1
# input: [1, 1], output: [0.17856420391819583], truth: 0
# input: [0, 0], output: [0.325167785648985], truth: 0
# input: [0, 1], output: [0.4179432021613231], truth: 1
# input: [1, 0], output: [0.05119508879757399], truth: 1
# input: [1, 1], output: [0.07510347154503672], truth: 0
# input: [0, 0], output: [0.19544101335291234], truth: 0
# input: [0, 1], output: [0.388383055058061], truth: 1
# input: [1, 0], output: [0.13492240060136698], truth: 1
# input: [1, 1], output: [0.2859690572120468], truth: 0
# input: [0, 0], output: [0.2541774063737069], truth: 0
# input: [0, 1], output: [0.332471431695915], truth: 1
# input: [1, 0], output: [0.07536203664423774], truth: 1
# input: [1, 1], output: [0.10609172894701298], truth: 0
# input: [0, 0], output: [0.35391200684397184], truth: 0
# input: [0, 1], output: [0.6490342837438935], truth: 1
# input: [1, 0], output: [0.3790918630958793], truth: 1
# input: [1, 1], output: [0.6717084516747734], truth: 0
# input: [0, 0], output: [0.21700174628500227], truth: 0
# input: [0, 1], output: [0.3983257329421286], truth: 1
# input: [1, 0], output: [0.22550376813891143], truth: 1
# input: [1, 1], output: [0.40699106694892956], truth: 0
# input: [0, 0], output: [0.4076354424590301], truth: 0
# input: [0, 1], output: [0.41213677156386075], truth: 1
# input: [1, 0], output: [0.20014032704148083], truth: 1
# input: [1, 1], output: [0.20244330094547244], truth: 0
# input: [0, 0], output: [0.17201684495623298], truth: 0
# input: [0, 1], output: [0.6297975367110548], truth: 1
# input: [1, 0], output: [0.11305006973710306], truth: 1
# input: [1, 1], output: [0.5086449452866199], truth: 0
# input: [0, 0], output: [0.11618164069120816], truth: 0
# input: [0, 1], output: [0.21661743975264366], truth: 1
# input: [1, 0], output: [0.06214021139571044], truth: 1
# input: [1, 1], output: [0.1160068446536598], truth: 0
# input: [0, 0], output: [0.2570493523297938], truth: 0
# input: [0, 1], output: [0.6269034692192016], truth: 1
# input: [1, 0], output: [0.15839194387154074], truth: 1
# input: [1, 1], output: [0.47290081197833284], truth: 0
# input: [0, 0], output: [0.3689470886631214], truth: 0
# input: [0, 1], output: [0.5291877154127912], truth: 1
# input: [1, 0], output: [0.20235121679448606], truth: 1
# input: [1, 1], output: [0.32702347215004074], truth: 0
# input: [0, 0], output: [0.2082489686938676], truth: 0
# input: [0, 1], output: [0.46898976239303997], truth: 1
# input: [1, 0], output: [0.09310212316729305], truth: 1
# input: [1, 1], output: [0.2459095928948915], truth: 0
# input: [0, 0], output: [0.11643928108407602], truth: 0
# input: [0, 1], output: [0.26602982803096253], truth: 1
# input: [1, 0], output: [0.09707307451559384], truth: 1
# input: [1, 1], output: [0.20834650912092897], truth: 0
# input: [0, 0], output: [0.38905696408353446], truth: 0
# input: [0, 1], output: [0.5772990587462256], truth: 1
# input: [1, 0], output: [0.054936734356300226], truth: 1
# input: [1, 1], output: [0.11534142067427203], truth: 0
# input: [0, 0], output: [0.3655576011192226], truth: 0
# input: [0, 1], output: [0.5687928481139438], truth: 1
# input: [1, 0], output: [0.16780398018446968], truth: 1
# input: [1, 1], output: [0.323353148432976], truth: 0
# input: [0, 0], output: [0.19073941771752026], truth: 0
# input: [0, 1], output: [0.4096436435889123], truth: 1
# input: [1, 0], output: [0.1675081488266667], truth: 1
# input: [1, 1], output: [0.3712480332139208], truth: 0
# input: [0, 0], output: [0.2786200489954625], truth: 0
# input: [0, 1], output: [0.555521958872092], truth: 1
# input: [1, 0], output: [0.14528321375685843], truth: 1
# input: [1, 1], output: [0.3548464940274492], truth: 0
# input: [0, 0], output: [0.38019474213767895], truth: 0
# input: [0, 1], output: [0.6306354077817223], truth: 1
# input: [1, 0], output: [0.24176610608606505], truth: 1
# input: [1, 1], output: [0.47225256692742396], truth: 0
# input: [0, 0], output: [0.3740895789437702], truth: 0
# input: [0, 1], output: [0.7823914706028555], truth: 1
# input: [1, 0], output: [0.12672168413032944], truth: 1
# input: [1, 1], output: [0.4678069713167634], truth: 0
# input: [0, 0], output: [0.36929816504696705], truth: 0
# input: [0, 1], output: [0.7613923793705895], truth: 1
# input: [1, 0], output: [0.2729876451874587], truth: 1
# input: [1, 1], output: [0.6270183147056438], truth: 0
# ---------------------------------------------------------------------------
# RecursionError                            Traceback (most recent call last)
# /Users/polya/workshop/playgrounds/NEAT_playground/nano_neat/prototyping.ipynb Cell 24 line 2
#       <a href='vscode-notebook-cell:/Users/polya/workshop/playgrounds/NEAT_playground/nano_neat/prototyping.ipynb#X36sZmlsZQ%3D%3D?line=0'>1</a> for i in range(20):
# ----> <a href='vscode-notebook-cell:/Users/polya/workshop/playgrounds/NEAT_playground/nano_neat/prototyping.ipynb#X36sZmlsZQ%3D%3D?line=1'>2</a>     p.run()
#
# /Users/polya/workshop/playgrounds/NEAT_playground/nano_neat/prototyping.ipynb Cell 24 line 7
#      <a href='vscode-notebook-cell:/Users/polya/workshop/playgrounds/NEAT_playground/nano_neat/prototyping.ipynb#X36sZmlsZQ%3D%3D?line=70'>71</a> GENERATION += 1
#      <a href='vscode-notebook-cell:/Users/polya/workshop/playgrounds/NEAT_playground/nano_neat/prototyping.ipynb#X36sZmlsZQ%3D%3D?line=71'>72</a> results = map(eval, self.genomes)
# ---> <a href='vscode-notebook-cell:/Users/polya/workshop/playgrounds/NEAT_playground/nano_neat/prototyping.ipynb#X36sZmlsZQ%3D%3D?line=72'>73</a> for (g, v) in zip(self.genomes, results): g.fitness = v
#      <a href='vscode-notebook-cell:/Users/polya/workshop/playgrounds/NEAT_playground/nano_neat/prototyping.ipynb#X36sZmlsZQ%3D%3D?line=73'>74</a> #for s in self.species: s.adjust_fitnesses()
#      <a href='vscode-notebook-cell:/Users/polya/workshop/playgrounds/NEAT_playground/nano_neat/prototyping.ipynb#X36sZmlsZQ%3D%3D?line=74'>75</a> self.genomes = sorted(self.genomes, reverse=True, key=lambda g: g.fitness)
#
# /Users/polya/workshop/playgrounds/NEAT_playground/nano_neat/prototyping.ipynb Cell 24 line 1
#       <a href='vscode-notebook-cell:/Users/polya/workshop/playgrounds/NEAT_playground/nano_neat/prototyping.ipynb#X36sZmlsZQ%3D%3D?line=8'>9</a> result = []
#      <a href='vscode-notebook-cell:/Users/polya/workshop/playgrounds/NEAT_playground/nano_neat/prototyping.ipynb#X36sZmlsZQ%3D%3D?line=9'>10</a> for i, iv in enumerate(INPUT):
# ---> <a href='vscode-notebook-cell:/Users/polya/workshop/playgrounds/NEAT_playground/nano_neat/prototyping.ipynb#X36sZmlsZQ%3D%3D?line=10'>11</a>     res= feed_forward(genome, input_values= dict(enumerate(iv)), activation_func=ACTIVATION_FUNC)
#      <a href='vscode-notebook-cell:/Users/polya/workshop/playgrounds/NEAT_playground/nano_neat/prototyping.ipynb#X36sZmlsZQ%3D%3D?line=11'>12</a>     print(f"input: {iv}, output: {res}, truth: {OUTPUT[i]}")
#      <a href='vscode-notebook-cell:/Users/polya/workshop/playgrounds/NEAT_playground/nano_neat/prototyping.ipynb#X36sZmlsZQ%3D%3D?line=12'>13</a>     result.append(res[0])
#
# /Users/polya/workshop/playgrounds/NEAT_playground/nano_neat/prototyping.ipynb Cell 24 line 4
#      <a href='vscode-notebook-cell:/Users/polya/workshop/playgrounds/NEAT_playground/nano_neat/prototyping.ipynb#X36sZmlsZQ%3D%3D?line=41'>42</a> global TO_DEBUG
#      <a href='vscode-notebook-cell:/Users/polya/workshop/playgrounds/NEAT_playground/nano_neat/prototyping.ipynb#X36sZmlsZQ%3D%3D?line=42'>43</a> TO_DEBUG = genome
# ---> <a href='vscode-notebook-cell:/Users/polya/workshop/playgrounds/NEAT_playground/nano_neat/prototyping.ipynb#X36sZmlsZQ%3D%3D?line=43'>44</a> raise e
#
# /Users/polya/workshop/playgrounds/NEAT_playground/nano_neat/prototyping.ipynb Cell 24 line 3
#      <a href='vscode-notebook-cell:/Users/polya/workshop/playgrounds/NEAT_playground/nano_neat/prototyping.ipynb#X36sZmlsZQ%3D%3D?line=31'>32</a>         values[node_id] = v
#      <a href='vscode-notebook-cell:/Users/polya/workshop/playgrounds/NEAT_playground/nano_neat/prototyping.ipynb#X36sZmlsZQ%3D%3D?line=32'>33</a>         return v
# ---> <a href='vscode-notebook-cell:/Users/polya/workshop/playgrounds/NEAT_playground/nano_neat/prototyping.ipynb#X36sZmlsZQ%3D%3D?line=33'>34</a> final = [eval_node(o.node_id) for o in all_output_nodes]
#      <a href='vscode-notebook-cell:/Users/polya/workshop/playgrounds/NEAT_playground/nano_neat/prototyping.ipynb#X36sZmlsZQ%3D%3D?line=34'>35</a> if len(final) == 0:
#      <a href='vscode-notebook-cell:/Users/polya/workshop/playgrounds/NEAT_playground/nano_neat/prototyping.ipynb#X36sZmlsZQ%3D%3D?line=35'>36</a>     print(f"genome: {genome} ")
#
# /Users/polya/workshop/playgrounds/NEAT_playground/nano_neat/prototyping.ipynb Cell 24 line 3
#      <a href='vscode-notebook-cell:/Users/polya/workshop/playgrounds/NEAT_playground/nano_neat/prototyping.ipynb#X36sZmlsZQ%3D%3D?line=31'>32</a>         values[node_id] = v
#      <a href='vscode-notebook-cell:/Users/polya/workshop/playgrounds/NEAT_playground/nano_neat/prototyping.ipynb#X36sZmlsZQ%3D%3D?line=32'>33</a>         return v
# ---> <a href='vscode-notebook-cell:/Users/polya/workshop/playgrounds/NEAT_playground/nano_neat/prototyping.ipynb#X36sZmlsZQ%3D%3D?line=33'>34</a> final = [eval_node(o.node_id) for o in all_output_nodes]
#      <a href='vscode-notebook-cell:/Users/polya/workshop/playgrounds/NEAT_playground/nano_neat/prototyping.ipynb#X36sZmlsZQ%3D%3D?line=34'>35</a> if len(final) == 0:
#      <a href='vscode-notebook-cell:/Users/polya/workshop/playgrounds/NEAT_playground/nano_neat/prototyping.ipynb#X36sZmlsZQ%3D%3D?line=35'>36</a>     print(f"genome: {genome} ")
#
# /Users/polya/workshop/playgrounds/NEAT_playground/nano_neat/prototyping.ipynb Cell 24 line 3
#      <a href='vscode-notebook-cell:/Users/polya/workshop/playgrounds/NEAT_playground/nano_neat/prototyping.ipynb#X36sZmlsZQ%3D%3D?line=27'>28</a> dependants = dependency_tree.get(node_id)
#      <a href='vscode-notebook-cell:/Users/polya/workshop/playgrounds/NEAT_playground/nano_neat/prototyping.ipynb#X36sZmlsZQ%3D%3D?line=28'>29</a> for conn in dependants:
# ---> <a href='vscode-notebook-cell:/Users/polya/workshop/playgrounds/NEAT_playground/nano_neat/prototyping.ipynb#X36sZmlsZQ%3D%3D?line=29'>30</a>     deps.append(eval_node(conn.in_node) * conn.weight)
#      <a href='vscode-notebook-cell:/Users/polya/workshop/playgrounds/NEAT_playground/nano_neat/prototyping.ipynb#X36sZmlsZQ%3D%3D?line=30'>31</a> v = activation_func(sum(deps))
#      <a href='vscode-notebook-cell:/Users/polya/workshop/playgrounds/NEAT_playground/nano_neat/prototyping.ipynb#X36sZmlsZQ%3D%3D?line=31'>32</a> values[node_id] = v
#
# /Users/polya/workshop/playgrounds/NEAT_playground/nano_neat/prototyping.ipynb Cell 24 line 3
#      <a href='vscode-notebook-cell:/Users/polya/workshop/playgrounds/NEAT_playground/nano_neat/prototyping.ipynb#X36sZmlsZQ%3D%3D?line=27'>28</a> dependants = dependency_tree.get(node_id)
#      <a href='vscode-notebook-cell:/Users/polya/workshop/playgrounds/NEAT_playground/nano_neat/prototyping.ipynb#X36sZmlsZQ%3D%3D?line=28'>29</a> for conn in dependants:
# ---> <a href='vscode-notebook-cell:/Users/polya/workshop/playgrounds/NEAT_playground/nano_neat/prototyping.ipynb#X36sZmlsZQ%3D%3D?line=29'>30</a>     deps.append(eval_node(conn.in_node) * conn.weight)
#      <a href='vscode-notebook-cell:/Users/polya/workshop/playgrounds/NEAT_playground/nano_neat/prototyping.ipynb#X36sZmlsZQ%3D%3D?line=30'>31</a> v = activation_func(sum(deps))
#      <a href='vscode-notebook-cell:/Users/polya/workshop/playgrounds/NEAT_playground/nano_neat/prototyping.ipynb#X36sZmlsZQ%3D%3D?line=31'>32</a> values[node_id] = v
#
#     [... skipping similar frames: feed_forward.<locals>.eval_node at line 30 (2967 times)]
#
# /Users/polya/workshop/playgrounds/NEAT_playground/nano_neat/prototyping.ipynb Cell 24 line 3
#      <a href='vscode-notebook-cell:/Users/polya/workshop/playgrounds/NEAT_playground/nano_neat/prototyping.ipynb#X36sZmlsZQ%3D%3D?line=27'>28</a> dependants = dependency_tree.get(node_id)
#      <a href='vscode-notebook-cell:/Users/polya/workshop/playgrounds/NEAT_playground/nano_neat/prototyping.ipynb#X36sZmlsZQ%3D%3D?line=28'>29</a> for conn in dependants:
# ---> <a href='vscode-notebook-cell:/Users/polya/workshop/playgrounds/NEAT_playground/nano_neat/prototyping.ipynb#X36sZmlsZQ%3D%3D?line=29'>30</a>     deps.append(eval_node(conn.in_node) * conn.weight)
#      <a href='vscode-notebook-cell:/Users/polya/workshop/playgrounds/NEAT_playground/nano_neat/prototyping.ipynb#X36sZmlsZQ%3D%3D?line=30'>31</a> v = activation_func(sum(deps))
#      <a href='vscode-notebook-cell:/Users/polya/workshop/playgrounds/NEAT_playground/nano_neat/prototyping.ipynb#X36sZmlsZQ%3D%3D?line=31'>32</a> values[node_id] = v
#
# RecursionError: maximum recursion depth exceeded

# %%
TO_DEBUG.connections
# Out:
# [Conn from 0 to 2, weight:-1.4362788240081585, en:True, innv:1,
#  Conn from 1 to 2, weight:0.024503715169874374, en:True, innv:2,
#  Conn from 3 to 2, weight:-1.628345334555162, en:True, innv:3,
#  Conn from 0 to 4, weight:0.4962756776287449, en:False, innv:4,
#  Conn from 1 to 4, weight:0.7979104178833114, en:True, innv:5,
#  Conn from 4 to 2, weight:-0.20350792353160796, en:True, innv:6,
#  Conn from 0 to 2, weight:1.0, en:True, innv:4,
#  Conn from 2 to 4, weight:0.4962756776287449, en:True, innv:5]

# %%
TO_DEBUG.connections[-1]
# Out:
# Conn from 2 to 4, weight:-0.4445488079575617, en:True, innv:5

# %%
TO_DEBUG.nodes
# Out:
# [input Node 0 ,
#  input Node 1 ,
#  output Node 2 ,
#  hidden Node 3 ,
#  hidden Node 4 ,
#  hidden Node 2 ]

# %%
for g in p.genomes: g.show()
# Out:
# example.html
# example.html
# example.html
# example.html
# example.html

# %%
TO_DEBUG.show()
# Out:
# example.html

# %%
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# /Users/polya/workshop/playgrounds/NEAT_playground/nano_neat/prototyping.ipynb Cell 28 line 1
# ----> <a href='vscode-notebook-cell:/Users/polya/workshop/playgrounds/NEAT_playground/nano_neat/prototyping.ipynb#X26sZmlsZQ%3D%3D?line=0'>1</a> TO_DEBUG.mark
#
# AttributeError: 'Genome' object has no attribute 'mark'

# %%
def test_crossover():
    g1 = Genome.construct_from_dict(
            nodes={
                1:Node(1, 'input'),
                2:Node(2, 'input'),
                3:Node(3, 'input'),
                4:Node(4, 'output'),
                5:Node(5),
            },
            connections={
                1:Connection(in_node=1, out_node=4),
                2:Connection(in_node=2, out_node=4, enabled=False),
                3:Connection(in_node=3, out_node=4),
                4:Connection(in_node=2, out_node=5),
                5:Connection(in_node=5, out_node=4 ),
                8:Connection(in_node=1, out_node=5),
            }
        )
    g2 = Genome.construct_from_dict(
            nodes={
                1:Node(1, 'input'),
                2:Node(2, 'input'),
                3:Node(3, 'input'),
                4:Node(4, 'output'),
                5:Node(5),
                6:Node(6),
            },
            connections= {
                1:Connection(in_node=1, out_node=4),
                2:Connection(in_node=2, out_node=4, enabled=False),
                3:Connection(in_node=3, out_node=4),
                4:Connection(in_node=2, out_node=5),
                5:Connection(in_node=5, out_node=4, enabled=False),
                6:Connection(in_node=5, out_node=6),
                7:Connection(in_node=6, out_node=4),
                9:Connection(in_node=3, out_node=5),
                10:Connection(in_node=1, out_node=6),
            }
        )
    #g1.show()
    #g2.show()
    g1.set_fitness(0.5)
    g2.set_fitness(0.5)
    c = crossover(g1,g2)
    c.show()
#test_crossover()

# %%
# One of the first tests, checking if structures were building correctly
gen = Genome()
gen.add_node('input') #     0
gen.add_node('input') #     1
gen.add_node('hidden')#     2
gen.add_node('output')#     3
gen.add_node('output')#     4
gen.add_connection(0,4, weight=0.8)
gen.add_connection(1,2, weight=0.8)
gen.add_connection(0,3, weight=0.8)
gen.add_connection(1,4, weight=0.8)
gen.add_connection(2,3, weight=0.8)
result = feed_forward(gen, {0:0.25, 1:0.5}, relu)
print("RESULT:", result)
